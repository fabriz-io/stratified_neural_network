# %% [markdown]
# # Demonstrational notebook: Stratified Neural Networks

# %% [markdown]
# This is a notebook for demonstrative purposes only. The used data is pruned to 500 features in order to be able to include the data file into the repo. For a custom analysis feel free to adjust the data path to a larger local file (to work with this notebook the data should be created and preprocessed with the provided files in this repo.). For comprehensive analysis please use the "train_models.py" file. Evaluation can be carried out with the "evaluate_models.py" file where paths should be adjusted to fit the needs.

# %%
# Import modules.
import torch
import torch.nn as nn
from sklearn.model_selection import StratifiedKFold
import pandas as pd
import numpy as np
import collections
import os
import shap
import matplotlib.pyplot as plt

from src.modules.evaluation_metrics import stratified_concordance_index, stratified_brier_score
from src.modules.torch_models import BaseFeedForwardNet, StratifiedPartialLikelihoodLoss, StratifiedRankingLoss

# %%
# Hyperparameters.
BRIER_EVAL_TIME = 1500 # Evaluation time for Brier Score early stopping criterium.
LEARNING_RATE = 0.0001
MAX_EPOCHS = 200
MIN_WIDTH = 10  # Minimum layer width.
MAX_WIDTH = 200  # Maximum layer width.
MIN_DEPTH = 2 # Minimum network depth.
MAX_DEPTH = 10 # Maximum network depth.
NO_OF_K_SPLITS = 5
SHAP_BACKGROUND_SIZE = 200
EVALUATION_TIMES_PEC = list(range(10, 1500, 30)) # Evaluation points in time for prediction error curves.

hyperparameters = {
    "BRIER_EVAL_TIME": BRIER_EVAL_TIME,
    "LEARNING_RATE": LEARNING_RATE,
    "MAX_EPOCHS": MAX_EPOCHS,
    "MIN_WIDTH": MIN_WIDTH,
    "MAX_WIDTH": MAX_WIDTH,
    "MIN_DEPTH": MIN_DEPTH,
    "MAX_DEPTH": MAX_DEPTH,
    "NO_OF_K_SPLITS": NO_OF_K_SPLITS,
    "SHAP_BACKGROUND_SIZE": SHAP_BACKGROUND_SIZE,
    "EVALUATION_TIMES_PEC": EVALUATION_TIMES_PEC
}

# %%
# Load Data.

data_path = "./demo_data_500_features.csv"
data = pd.read_csv(data_path)
data.index = data.patient_id

gene_counts = data.iloc[:, 5:]
gene_counts_dim = gene_counts.shape[1]
gene_names = gene_counts.columns
event_indicator = data.event.to_numpy(dtype=np.bool)
event_time = data.time.to_numpy(dtype=np.int16)
strata = data.tumor_type.to_numpy(dtype=np.str)
patient_id = data.patient_id.to_numpy()

# %%
# Additional Neural Network settings.
print("Preparing Neural Network...")

def weights_init(m):
    try:
        nn.init.xavier_uniform_(m.weight.data)
        nn.init.zeros_(m.bias.data)
    except:
        pass

# Note: For unstratified models the argument "strata=None" is parsed later.
configs = {
    "Partial Likelihood": StratifiedPartialLikelihoodLoss,
    "Stratified Partial Likelihood": StratifiedPartialLikelihoodLoss,
    "Ranking Loss": StratifiedRankingLoss,
    "Stratified Ranking Loss": StratifiedRankingLoss
}

# k-Fold cross-validation
kf = StratifiedKFold(n_splits=NO_OF_K_SPLITS, shuffle=True, random_state=42)

print("Done.")

# %% Load summary files or create placeholders for evaluation metrics if they dont' exist.

try:
    prediction_error_curves_PartialLikelihood = pd.read_csv("./summary/pec_pl.csv", index_col=0)
    prediction_error_curves_StratifiedPartialLikelihood = pd.read_csv("./summary/pec_spl.csv", index_col=0)
    prediction_error_curves_RankingLoss = pd.read_csv("./summary/pec_rl.csv", index_col=0)
    prediction_error_curves_StratifiedRankingLoss = pd.read_csv("./summary/pec_srl.csv", index_col=0)

    concordance_index_summary_df = pd.read_csv("./summary/concordance_index.csv")

except:
    # Empty placeholder for PECs.
    prediction_error_curves_PartialLikelihood = pd.DataFrame(columns=[str(t) for t in EVALUATION_TIMES_PEC])
    prediction_error_curves_StratifiedPartialLikelihood = pd.DataFrame(columns=[str(t) for t in EVALUATION_TIMES_PEC])
    prediction_error_curves_RankingLoss = pd.DataFrame(columns=[str(t) for t in EVALUATION_TIMES_PEC])
    prediction_error_curves_StratifiedRankingLoss = pd.DataFrame(columns=[str(t) for t in EVALUATION_TIMES_PEC])

    # Placeholder for concordance index scores.
    concordance_index_summary_df = pd.DataFrame(columns=configs.keys())


# Placeholder for Shap values.
shap_values_PartialLikelihood = pd.DataFrame(index=patient_id, columns=gene_names)
shap_values_StratifiedPartialLikelihood = pd.DataFrame(index=patient_id, columns=gene_names)
shap_values_RankingLoss = pd.DataFrame(index=patient_id, columns=gene_names)
shap_values_StratifiedRankingLoss = pd.DataFrame(index=patient_id, columns=gene_names)
# Out:
# Preparing Neural Network...
# Done.

# %%
# Fit models.
print("Start fitting models...")

# Generate random layer depth and widths. Order widths descending.
hidden_layers = np.random.randint(MIN_WIDTH, MAX_WIDTH, np.random.randint(MIN_DEPTH, MAX_DEPTH))
HIDDEN_LAYERS = hidden_layers[np.argsort(-hidden_layers)]
split_no = 1
for train_idx, test_idx in kf.split(gene_counts, y=strata):

    # Data and PyTorch Tensor initialization.
    gene_counts_train = gene_counts.iloc[train_idx]
    gene_counts_test = gene_counts.iloc[test_idx]
    patient_id_train = gene_counts_train.index
    patient_id_test = gene_counts_test.index
    event_indicator_train = event_indicator[train_idx]
    event_indicator_test = event_indicator[test_idx]
    event_time_train = event_time[train_idx]
    event_time_test = event_time[test_idx]
    X_train = torch.tensor(gene_counts_train.to_numpy(), requires_grad=False, dtype=torch.float32)
    X_test = torch.tensor(gene_counts_test.to_numpy(), requires_grad=False, dtype=torch.float32)

    # Background samples for shap value estimation.
    shap_background = X_train[np.random.choice(X_train.size()[0], SHAP_BACKGROUND_SIZE, replace=False)]

    # Structured arrays for Brier Score Evaluation.
    survival_data_train = np.zeros(event_indicator_train.shape[0],
        dtype={'names':('event_indicator', 'event_time'), 'formats':('bool', 'u2')})
    survival_data_train['event_indicator'] = event_indicator_train
    survival_data_train['event_time'] = event_time_train
    survival_data_test = np.zeros(event_indicator_test.shape[0],
        dtype={'names':('event_indicator', 'event_time'), 'formats':('bool', 'u2')})
    survival_data_test['event_indicator'] = event_indicator_test
    survival_data_test['event_time'] = event_time_test

    # Initialize model with given configs.
    current_concordance_index = []
    for loss_name, loss_function in configs.items():           
        try:
            # Clean up if model exists.
            del net
        except:
            pass
        finally:
            net = BaseFeedForwardNet(gene_counts_dim, 1, hidden_dims=HIDDEN_LAYERS)
            optimizer = torch.optim.Adam(net.parameters(), lr=LEARNING_RATE)
            net.apply(weights_init)
        print("\n\n")
        print("________________________________________________________________")
        print("Split/Total Splits: {}/{}".format(split_no, NO_OF_K_SPLITS))
        print("Model             : {}".format(loss_name))
        print("Hidden Layers     : {}".format(HIDDEN_LAYERS))
        print("\n")
        loss_func = loss_function()

        # Monitor the last four brier scores.
        recent_brier_scores = collections.deque([1.0, 1.0, 1.0, 1.0])
        top_brier_score = 1.0

        # Stratificaion.
        if "Stratified" in loss_name:
            strata_train = strata[train_idx]
            strata_test = strata[test_idx]
        else:
            strata_train = np.full(len(event_indicator_train), "NOT STRATIFIED")
            strata_test = np.full(len(event_indicator_test), "NOT STRATIFIED")
        strata_test_c_index = strata[test_idx]

        # Start Training.
        for epoch in range(MAX_EPOCHS):
            # Training Phase.
            net.train()
            optimizer.zero_grad()
            output_train = net(X_train)
            loss = loss_func(output_train,
                            event_time_train,
                            event_indicator_train,
                            strata=strata_train)
            loss.backward()
            optimizer.step()

            # Evaluation Phase ___________________________________________
            net.eval()
            with torch.no_grad():
                numpy_output_train = torch.squeeze(output_train.detach(), dim=1).numpy()
                numpy_output_test = torch.squeeze(net(X_test).detach(), dim=1).numpy()
                new_brier_score = stratified_brier_score(BRIER_EVAL_TIME,
                                                         survival_data_train,
                                                         survival_data_test,
                                                         numpy_output_train,
                                                         numpy_output_test, 
                                                         strata_train=strata_train,
                                                         strata_test=strata_test)
                c_index = stratified_concordance_index(numpy_output_test, event_indicator_test, event_time_test, strata_test_c_index) 

            # Early stopping criterium.
            if (new_brier_score > recent_brier_scores[-1] and epoch > 10) or epoch == MAX_EPOCHS - 1:
                e = shap.DeepExplainer(net, shap_background)
                shap_values = e.shap_values(X_test)
                prediction_error_curve = pd.Series(
                    [stratified_brier_score(t,
                                            survival_data_train,
                                            survival_data_test,
                                            numpy_output_train,
                                            numpy_output_test, 
                                            strata_train=strata_train,
                                            strata_test=strata_test
                                            )
                        for t in EVALUATION_TIMES_PEC
                    ], index=[str(t) for t in EVALUATION_TIMES_PEC])
                if loss_name == "Partial Likelihood":
                    prediction_error_curves_PartialLikelihood = \
                        prediction_error_curves_PartialLikelihood.append(prediction_error_curve, ignore_index=True)
                    
                    shap_values_PartialLikelihood.loc[patient_id_test] = shap_values
                elif loss_name == "Stratified Partial Likelihood":
                    prediction_error_curves_StratifiedPartialLikelihood = \
                        prediction_error_curves_StratifiedPartialLikelihood.append(prediction_error_curve, ignore_index=True)
                    shap_values_StratifiedPartialLikelihood.loc[patient_id_test] = shap_values
                elif loss_name == "Ranking Loss":
                    prediction_error_curves_RankingLoss = \
                        prediction_error_curves_RankingLoss.append(prediction_error_curve, ignore_index=True)
                    shap_values_RankingLoss.loc[patient_id_test] = shap_values
                elif loss_name == "Stratified Ranking Loss":
                    prediction_error_curves_StratifiedRankingLoss = \
                        prediction_error_curves_StratifiedRankingLoss.append(prediction_error_curve, ignore_index=True)
                    shap_values_StratifiedRankingLoss.loc[patient_id_test] = shap_values
                # Concordance Index
                current_concordance_index.append(c_index)
                break
            elif new_brier_score < top_brier_score:
                top_brier_score = new_brier_score
            recent_brier_scores.appendleft(new_brier_score)
            recent_brier_scores.pop()
            print("Epoch: {:3d} | Loss: {:.2f} | C-Index: {:.4f} | Brier Score: {:.4f}".format(epoch, loss.item(), c_index, new_brier_score))

    concordance_index_summary_df = concordance_index_summary_df.append(pd.Series(current_concordance_index, index=configs.keys()), ignore_index=True)
    split_no += 1
# Out:
# Start fitting models...
#
#
#
# ________________________________________________________________
# Split/Total Splits: 1/5
# Model             : Partial Likelihood
# Hidden Layers     : [30 10]
#
#
# Epoch:   0 | Loss: 2519.20 | C-Index: 0.5273 | Brier Score: 0.2222
# Epoch:   1 | Loss: 2512.69 | C-Index: 0.5274 | Brier Score: 0.2214
# Epoch:   2 | Loss: 2506.33 | C-Index: 0.5267 | Brier Score: 0.2206
# Epoch:   3 | Loss: 2500.09 | C-Index: 0.5257 | Brier Score: 0.2198
# Epoch:   4 | Loss: 2494.02 | C-Index: 0.5230 | Brier Score: 0.2190
# Epoch:   5 | Loss: 2488.12 | C-Index: 0.5221 | Brier Score: 0.2183
# Epoch:   6 | Loss: 2482.34 | C-Index: 0.5220 | Brier Score: 0.2176
# Epoch:   7 | Loss: 2476.69 | C-Index: 0.5208 | Brier Score: 0.2169
# Epoch:   8 | Loss: 2471.17 | C-Index: 0.5227 | Brier Score: 0.2162
# Epoch:   9 | Loss: 2465.76 | C-Index: 0.5252 | Brier Score: 0.2155
# Epoch:  10 | Loss: 2460.45 | C-Index: 0.5260 | Brier Score: 0.2148
# Epoch:  11 | Loss: 2455.28 | C-Index: 0.5285 | Brier Score: 0.2142
# Epoch:  12 | Loss: 2450.22 | C-Index: 0.5336 | Brier Score: 0.2135
# Epoch:  13 | Loss: 2445.30 | C-Index: 0.5361 | Brier Score: 0.2128
# Epoch:  14 | Loss: 2440.48 | C-Index: 0.5405 | Brier Score: 0.2120
# Epoch:  15 | Loss: 2435.76 | C-Index: 0.5464 | Brier Score: 0.2113
# Epoch:  16 | Loss: 2431.15 | C-Index: 0.5485 | Brier Score: 0.2106
# Epoch:  17 | Loss: 2426.66 | C-Index: 0.5519 | Brier Score: 0.2099
# Epoch:  18 | Loss: 2422.24 | C-Index: 0.5547 | Brier Score: 0.2091
# Epoch:  19 | Loss: 2417.92 | C-Index: 0.5571 | Brier Score: 0.2084
# Epoch:  20 | Loss: 2413.68 | C-Index: 0.5607 | Brier Score: 0.2078
# Epoch:  21 | Loss: 2409.48 | C-Index: 0.5647 | Brier Score: 0.2071
# Epoch:  22 | Loss: 2405.34 | C-Index: 0.5655 | Brier Score: 0.2064
# Epoch:  23 | Loss: 2401.30 | C-Index: 0.5683 | Brier Score: 0.2058
# Epoch:  24 | Loss: 2397.35 | C-Index: 0.5728 | Brier Score: 0.2052
# Epoch:  25 | Loss: 2393.47 | C-Index: 0.5776 | Brier Score: 0.2045
# Epoch:  26 | Loss: 2389.59 | C-Index: 0.5815 | Brier Score: 0.2039
# Epoch:  27 | Loss: 2385.79 | C-Index: 0.5867 | Brier Score: 0.2033
# Epoch:  28 | Loss: 2382.02 | C-Index: 0.5891 | Brier Score: 0.2027
# Epoch:  29 | Loss: 2378.31 | C-Index: 0.5917 | Brier Score: 0.2021
# Epoch:  30 | Loss: 2374.69 | C-Index: 0.5941 | Brier Score: 0.2015
# Epoch:  31 | Loss: 2371.12 | C-Index: 0.5983 | Brier Score: 0.2010
# Epoch:  32 | Loss: 2367.62 | C-Index: 0.6025 | Brier Score: 0.2004
# Epoch:  33 | Loss: 2364.16 | C-Index: 0.6051 | Brier Score: 0.1999
# Epoch:  34 | Loss: 2360.74 | C-Index: 0.6075 | Brier Score: 0.1993
# Epoch:  35 | Loss: 2357.36 | C-Index: 0.6110 | Brier Score: 0.1987
# Epoch:  36 | Loss: 2354.01 | C-Index: 0.6138 | Brier Score: 0.1982
# Epoch:  37 | Loss: 2350.70 | C-Index: 0.6172 | Brier Score: 0.1977
# Epoch:  38 | Loss: 2347.42 | C-Index: 0.6200 | Brier Score: 0.1972
# Epoch:  39 | Loss: 2344.15 | C-Index: 0.6236 | Brier Score: 0.1967
# Epoch:  40 | Loss: 2340.93 | C-Index: 0.6271 | Brier Score: 0.1962
# Epoch:  41 | Loss: 2337.76 | C-Index: 0.6290 | Brier Score: 0.1957
# Epoch:  42 | Loss: 2334.61 | C-Index: 0.6311 | Brier Score: 0.1952
# Epoch:  43 | Loss: 2331.47 | C-Index: 0.6333 | Brier Score: 0.1948
# Epoch:  44 | Loss: 2328.37 | C-Index: 0.6368 | Brier Score: 0.1943
# Epoch:  45 | Loss: 2325.30 | C-Index: 0.6386 | Brier Score: 0.1939
# Epoch:  46 | Loss: 2322.26 | C-Index: 0.6407 | Brier Score: 0.1935
# Epoch:  47 | Loss: 2319.27 | C-Index: 0.6432 | Brier Score: 0.1931
# Epoch:  48 | Loss: 2316.29 | C-Index: 0.6451 | Brier Score: 0.1927
# Epoch:  49 | Loss: 2313.34 | C-Index: 0.6467 | Brier Score: 0.1923
# Epoch:  50 | Loss: 2310.41 | C-Index: 0.6466 | Brier Score: 0.1919
# Epoch:  51 | Loss: 2307.50 | C-Index: 0.6477 | Brier Score: 0.1916
# Epoch:  52 | Loss: 2304.61 | C-Index: 0.6486 | Brier Score: 0.1912
# Epoch:  53 | Loss: 2301.75 | C-Index: 0.6488 | Brier Score: 0.1909
# Epoch:  54 | Loss: 2298.92 | C-Index: 0.6494 | Brier Score: 0.1905
# Epoch:  55 | Loss: 2296.12 | C-Index: 0.6514 | Brier Score: 0.1902
# Epoch:  56 | Loss: 2293.34 | C-Index: 0.6526 | Brier Score: 0.1898
# Epoch:  57 | Loss: 2290.59 | C-Index: 0.6548 | Brier Score: 0.1895
# Epoch:  58 | Loss: 2287.87 | C-Index: 0.6556 | Brier Score: 0.1891
# Epoch:  59 | Loss: 2285.20 | C-Index: 0.6569 | Brier Score: 0.1887
# Epoch:  60 | Loss: 2282.56 | C-Index: 0.6584 | Brier Score: 0.1884
# Epoch:  61 | Loss: 2279.95 | C-Index: 0.6578 | Brier Score: 0.1881
# Epoch:  62 | Loss: 2277.38 | C-Index: 0.6573 | Brier Score: 0.1877
# Epoch:  63 | Loss: 2274.82 | C-Index: 0.6581 | Brier Score: 0.1874
# Epoch:  64 | Loss: 2272.29 | C-Index: 0.6588 | Brier Score: 0.1871
# Epoch:  65 | Loss: 2269.77 | C-Index: 0.6587 | Brier Score: 0.1868
# Epoch:  66 | Loss: 2267.29 | C-Index: 0.6594 | Brier Score: 0.1865
# Epoch:  67 | Loss: 2264.83 | C-Index: 0.6603 | Brier Score: 0.1862
# Epoch:  68 | Loss: 2262.40 | C-Index: 0.6606 | Brier Score: 0.1859
# Epoch:  69 | Loss: 2260.00 | C-Index: 0.6606 | Brier Score: 0.1856
# Epoch:  70 | Loss: 2257.63 | C-Index: 0.6616 | Brier Score: 0.1854
# Epoch:  71 | Loss: 2255.28 | C-Index: 0.6620 | Brier Score: 0.1851
# Epoch:  72 | Loss: 2252.97 | C-Index: 0.6631 | Brier Score: 0.1849
# Epoch:  73 | Loss: 2250.68 | C-Index: 0.6631 | Brier Score: 0.1846
# Epoch:  74 | Loss: 2248.41 | C-Index: 0.6628 | Brier Score: 0.1844
# Epoch:  75 | Loss: 2246.16 | C-Index: 0.6626 | Brier Score: 0.1842
# Epoch:  76 | Loss: 2243.94 | C-Index: 0.6626 | Brier Score: 0.1840
# Epoch:  77 | Loss: 2241.76 | C-Index: 0.6620 | Brier Score: 0.1839
# Epoch:  78 | Loss: 2239.60 | C-Index: 0.6623 | Brier Score: 0.1837
# Epoch:  79 | Loss: 2237.47 | C-Index: 0.6625 | Brier Score: 0.1835
# Epoch:  80 | Loss: 2235.40 | C-Index: 0.6623 | Brier Score: 0.1834
# Epoch:  81 | Loss: 2233.37 | C-Index: 0.6620 | Brier Score: 0.1832
# Epoch:  82 | Loss: 2231.36 | C-Index: 0.6622 | Brier Score: 0.1831
# Epoch:  83 | Loss: 2229.38 | C-Index: 0.6619 | Brier Score: 0.1829
# Epoch:  84 | Loss: 2227.42 | C-Index: 0.6619 | Brier Score: 0.1828
# Epoch:  85 | Loss: 2225.48 | C-Index: 0.6628 | Brier Score: 0.1827
# Epoch:  86 | Loss: 2223.57 | C-Index: 0.6626 | Brier Score: 0.1825
# Epoch:  87 | Loss: 2221.68 | C-Index: 0.6626 | Brier Score: 0.1824
# Epoch:  88 | Loss: 2219.83 | C-Index: 0.6626 | Brier Score: 0.1823
# Epoch:  89 | Loss: 2218.01 | C-Index: 0.6628 | Brier Score: 0.1822
# Epoch:  90 | Loss: 2216.21 | C-Index: 0.6634 | Brier Score: 0.1821
# Epoch:  91 | Loss: 2214.43 | C-Index: 0.6629 | Brier Score: 0.1820
# Epoch:  92 | Loss: 2212.69 | C-Index: 0.6632 | Brier Score: 0.1819
# Epoch:  93 | Loss: 2210.97 | C-Index: 0.6638 | Brier Score: 0.1818
# Epoch:  94 | Loss: 2209.27 | C-Index: 0.6631 | Brier Score: 0.1817
# Epoch:  95 | Loss: 2207.59 | C-Index: 0.6635 | Brier Score: 0.1816
# Epoch:  96 | Loss: 2205.92 | C-Index: 0.6632 | Brier Score: 0.1815
# Epoch:  97 | Loss: 2204.27 | C-Index: 0.6626 | Brier Score: 0.1814
# Epoch:  98 | Loss: 2202.64 | C-Index: 0.6625 | Brier Score: 0.1814
# Epoch:  99 | Loss: 2201.04 | C-Index: 0.6631 | Brier Score: 0.1813
# Epoch: 100 | Loss: 2199.46 | C-Index: 0.6628 | Brier Score: 0.1813
# Epoch: 101 | Loss: 2197.90 | C-Index: 0.6631 | Brier Score: 0.1812
# Epoch: 102 | Loss: 2196.37 | C-Index: 0.6637 | Brier Score: 0.1812
# Epoch: 103 | Loss: 2194.85 | C-Index: 0.6640 | Brier Score: 0.1811
# Epoch: 104 | Loss: 2193.36 | C-Index: 0.6640 | Brier Score: 0.1811
# Epoch: 105 | Loss: 2191.89 | C-Index: 0.6641 | Brier Score: 0.1810
# Epoch: 106 | Loss: 2190.44 | C-Index: 0.6644 | Brier Score: 0.1810
# Epoch: 107 | Loss: 2189.00 | C-Index: 0.6647 | Brier Score: 0.1809
# Epoch: 108 | Loss: 2187.57 | C-Index: 0.6644 | Brier Score: 0.1809
# Epoch: 109 | Loss: 2186.14 | C-Index: 0.6641 | Brier Score: 0.1808
# Epoch: 110 | Loss: 2184.72 | C-Index: 0.6638 | Brier Score: 0.1808
# Epoch: 111 | Loss: 2183.31 | C-Index: 0.6638 | Brier Score: 0.1807
# Epoch: 112 | Loss: 2181.92 | C-Index: 0.6644 | Brier Score: 0.1807
# Epoch: 113 | Loss: 2180.55 | C-Index: 0.6646 | Brier Score: 0.1807
# Epoch: 114 | Loss: 2179.19 | C-Index: 0.6646 | Brier Score: 0.1806
# Epoch: 115 | Loss: 2177.87 | C-Index: 0.6646 | Brier Score: 0.1806
# Epoch: 116 | Loss: 2176.56 | C-Index: 0.6640 | Brier Score: 0.1806
# Epoch: 117 | Loss: 2175.27 | C-Index: 0.6641 | Brier Score: 0.1805
# Epoch: 118 | Loss: 2174.00 | C-Index: 0.6640 | Brier Score: 0.1805
# Epoch: 119 | Loss: 2172.75 | C-Index: 0.6643 | Brier Score: 0.1805
# Epoch: 120 | Loss: 2171.51 | C-Index: 0.6641 | Brier Score: 0.1805
# Epoch: 121 | Loss: 2170.28 | C-Index: 0.6634 | Brier Score: 0.1804
# Epoch: 122 | Loss: 2169.07 | C-Index: 0.6628 | Brier Score: 0.1804
# Epoch: 123 | Loss: 2167.86 | C-Index: 0.6629 | Brier Score: 0.1804
# Epoch: 124 | Loss: 2166.69 | C-Index: 0.6626 | Brier Score: 0.1804
# Epoch: 125 | Loss: 2165.53 | C-Index: 0.6629 | Brier Score: 0.1804
# Epoch: 126 | Loss: 2164.38 | C-Index: 0.6628 | Brier Score: 0.1803
# Epoch: 127 | Loss: 2163.24 | C-Index: 0.6631 | Brier Score: 0.1803
# Epoch: 128 | Loss: 2162.11 | C-Index: 0.6632 | Brier Score: 0.1803
# Epoch: 129 | Loss: 2161.00 | C-Index: 0.6635 | Brier Score: 0.1803
# Epoch: 130 | Loss: 2159.89 | C-Index: 0.6635 | Brier Score: 0.1803
# Epoch: 131 | Loss: 2158.79 | C-Index: 0.6625 | Brier Score: 0.1803
# Epoch: 132 | Loss: 2157.71 | C-Index: 0.6626 | Brier Score: 0.1803
# Epoch: 133 | Loss: 2156.63 | C-Index: 0.6625 | Brier Score: 0.1803
#
#
#
# ________________________________________________________________
# Split/Total Splits: 1/5
# Model             : Stratified Partial Likelihood
# Hidden Layers     : [30 10]
#
#
# Epoch:   0 | Loss: 2173.24 | C-Index: 0.4994 | Brier Score: 0.2346
# Epoch:   1 | Loss: 2161.93 | C-Index: 0.5034 | Brier Score: 0.2326
# Epoch:   2 | Loss: 2150.96 | C-Index: 0.5074 | Brier Score: 0.2306
# Epoch:   3 | Loss: 2140.34 | C-Index: 0.5131 | Brier Score: 0.2287
# Epoch:   4 | Loss: 2129.96 | C-Index: 0.5215 | Brier Score: 0.2269
# Epoch:   5 | Loss: 2119.99 | C-Index: 0.5270 | Brier Score: 0.2252
# Epoch:   6 | Loss: 2110.37 | C-Index: 0.5302 | Brier Score: 0.2235
# Epoch:   7 | Loss: 2101.08 | C-Index: 0.5335 | Brier Score: 0.2219
# Epoch:   8 | Loss: 2092.13 | C-Index: 0.5363 | Brier Score: 0.2204
# Epoch:   9 | Loss: 2083.51 | C-Index: 0.5394 | Brier Score: 0.2189
# Epoch:  10 | Loss: 2075.26 | C-Index: 0.5444 | Brier Score: 0.2176
# Epoch:  11 | Loss: 2067.38 | C-Index: 0.5482 | Brier Score: 0.2164
# Epoch:  12 | Loss: 2059.79 | C-Index: 0.5537 | Brier Score: 0.2153
# Epoch:  13 | Loss: 2052.49 | C-Index: 0.5584 | Brier Score: 0.2142
# Epoch:  14 | Loss: 2045.49 | C-Index: 0.5610 | Brier Score: 0.2132
# Epoch:  15 | Loss: 2038.80 | C-Index: 0.5656 | Brier Score: 0.2123
# Epoch:  16 | Loss: 2032.39 | C-Index: 0.5697 | Brier Score: 0.2114
# Epoch:  17 | Loss: 2026.24 | C-Index: 0.5736 | Brier Score: 0.2105
# Epoch:  18 | Loss: 2020.31 | C-Index: 0.5767 | Brier Score: 0.2097
# Epoch:  19 | Loss: 2014.58 | C-Index: 0.5802 | Brier Score: 0.2090
# Epoch:  20 | Loss: 2009.07 | C-Index: 0.5833 | Brier Score: 0.2084
# Epoch:  21 | Loss: 2003.77 | C-Index: 0.5858 | Brier Score: 0.2078
# Epoch:  22 | Loss: 1998.67 | C-Index: 0.5864 | Brier Score: 0.2073
# Epoch:  23 | Loss: 1993.74 | C-Index: 0.5879 | Brier Score: 0.2068
# Epoch:  24 | Loss: 1988.97 | C-Index: 0.5888 | Brier Score: 0.2063
# Epoch:  25 | Loss: 1984.40 | C-Index: 0.5904 | Brier Score: 0.2059
# Epoch:  26 | Loss: 1979.96 | C-Index: 0.5938 | Brier Score: 0.2055
# Epoch:  27 | Loss: 1975.64 | C-Index: 0.5961 | Brier Score: 0.2051
# Epoch:  28 | Loss: 1971.47 | C-Index: 0.5975 | Brier Score: 0.2047
# Epoch:  29 | Loss: 1967.44 | C-Index: 0.6001 | Brier Score: 0.2044
# Epoch:  30 | Loss: 1963.55 | C-Index: 0.6019 | Brier Score: 0.2040
# Epoch:  31 | Loss: 1959.76 | C-Index: 0.6035 | Brier Score: 0.2037
# Epoch:  32 | Loss: 1956.09 | C-Index: 0.6038 | Brier Score: 0.2035
# Epoch:  33 | Loss: 1952.51 | C-Index: 0.6056 | Brier Score: 0.2032
# Epoch:  34 | Loss: 1949.03 | C-Index: 0.6068 | Brier Score: 0.2030
# Epoch:  35 | Loss: 1945.61 | C-Index: 0.6073 | Brier Score: 0.2027
# Epoch:  36 | Loss: 1942.27 | C-Index: 0.6090 | Brier Score: 0.2025
# Epoch:  37 | Loss: 1939.00 | C-Index: 0.6101 | Brier Score: 0.2023
# Epoch:  38 | Loss: 1935.82 | C-Index: 0.6116 | Brier Score: 0.2021
# Epoch:  39 | Loss: 1932.69 | C-Index: 0.6121 | Brier Score: 0.2019
# Epoch:  40 | Loss: 1929.64 | C-Index: 0.6131 | Brier Score: 0.2018
# Epoch:  41 | Loss: 1926.64 | C-Index: 0.6149 | Brier Score: 0.2017
# Epoch:  42 | Loss: 1923.70 | C-Index: 0.6155 | Brier Score: 0.2016
# Epoch:  43 | Loss: 1920.84 | C-Index: 0.6171 | Brier Score: 0.2015
# Epoch:  44 | Loss: 1918.03 | C-Index: 0.6185 | Brier Score: 0.2014
# Epoch:  45 | Loss: 1915.26 | C-Index: 0.6196 | Brier Score: 0.2013
# Epoch:  46 | Loss: 1912.55 | C-Index: 0.6205 | Brier Score: 0.2012
# Epoch:  47 | Loss: 1909.88 | C-Index: 0.6209 | Brier Score: 0.2012
# Epoch:  48 | Loss: 1907.25 | C-Index: 0.6209 | Brier Score: 0.2011
# Epoch:  49 | Loss: 1904.68 | C-Index: 0.6219 | Brier Score: 0.2010
# Epoch:  50 | Loss: 1902.14 | C-Index: 0.6216 | Brier Score: 0.2010
# Epoch:  51 | Loss: 1899.62 | C-Index: 0.6221 | Brier Score: 0.2009
# Epoch:  52 | Loss: 1897.14 | C-Index: 0.6224 | Brier Score: 0.2009
# Epoch:  53 | Loss: 1894.71 | C-Index: 0.6230 | Brier Score: 0.2008
# Epoch:  54 | Loss: 1892.33 | C-Index: 0.6230 | Brier Score: 0.2008
# Epoch:  55 | Loss: 1889.98 | C-Index: 0.6237 | Brier Score: 0.2007
# Epoch:  56 | Loss: 1887.67 | C-Index: 0.6240 | Brier Score: 0.2007
# Epoch:  57 | Loss: 1885.38 | C-Index: 0.6244 | Brier Score: 0.2006
# Epoch:  58 | Loss: 1883.12 | C-Index: 0.6246 | Brier Score: 0.2006
# Epoch:  59 | Loss: 1880.89 | C-Index: 0.6256 | Brier Score: 0.2006
# Epoch:  60 | Loss: 1878.67 | C-Index: 0.6268 | Brier Score: 0.2005
# Epoch:  61 | Loss: 1876.47 | C-Index: 0.6277 | Brier Score: 0.2005
# Epoch:  62 | Loss: 1874.29 | C-Index: 0.6284 | Brier Score: 0.2005
# Epoch:  63 | Loss: 1872.14 | C-Index: 0.6292 | Brier Score: 0.2005
# Epoch:  64 | Loss: 1870.02 | C-Index: 0.6296 | Brier Score: 0.2005
# Epoch:  65 | Loss: 1867.92 | C-Index: 0.6302 | Brier Score: 0.2005
# Epoch:  66 | Loss: 1865.84 | C-Index: 0.6323 | Brier Score: 0.2005
# Epoch:  67 | Loss: 1863.77 | C-Index: 0.6317 | Brier Score: 0.2005
#
#
#
# ________________________________________________________________
# Split/Total Splits: 1/5
# Model             : Ranking Loss
# Hidden Layers     : [30 10]
#
#
# Epoch:   0 | Loss: 0.47 | C-Index: 0.4649 | Brier Score: 0.2385
# Epoch:   1 | Loss: 0.44 | C-Index: 0.4667 | Brier Score: 0.2374
# Epoch:   2 | Loss: 0.42 | C-Index: 0.4692 | Brier Score: 0.2364
# Epoch:   3 | Loss: 0.39 | C-Index: 0.4712 | Brier Score: 0.2354
# Epoch:   4 | Loss: 0.37 | C-Index: 0.4740 | Brier Score: 0.2345
# Epoch:   5 | Loss: 0.35 | C-Index: 0.4764 | Brier Score: 0.2335
# Epoch:   6 | Loss: 0.33 | C-Index: 0.4782 | Brier Score: 0.2326
# Epoch:   7 | Loss: 0.31 | C-Index: 0.4814 | Brier Score: 0.2317
# Epoch:   8 | Loss: 0.28 | C-Index: 0.4823 | Brier Score: 0.2309
# Epoch:   9 | Loss: 0.26 | C-Index: 0.4860 | Brier Score: 0.2302
# Epoch:  10 | Loss: 0.25 | C-Index: 0.4884 | Brier Score: 0.2295
# Epoch:  11 | Loss: 0.23 | C-Index: 0.4907 | Brier Score: 0.2289
# Epoch:  12 | Loss: 0.21 | C-Index: 0.4920 | Brier Score: 0.2283
# Epoch:  13 | Loss: 0.19 | C-Index: 0.4954 | Brier Score: 0.2277
# Epoch:  14 | Loss: 0.17 | C-Index: 0.4994 | Brier Score: 0.2271
# Epoch:  15 | Loss: 0.16 | C-Index: 0.5010 | Brier Score: 0.2266
# Epoch:  16 | Loss: 0.14 | C-Index: 0.5056 | Brier Score: 0.2261
# Epoch:  17 | Loss: 0.12 | C-Index: 0.5102 | Brier Score: 0.2256
# Epoch:  18 | Loss: 0.11 | C-Index: 0.5119 | Brier Score: 0.2252
# Epoch:  19 | Loss: 0.09 | C-Index: 0.5115 | Brier Score: 0.2248
# Epoch:  20 | Loss: 0.08 | C-Index: 0.5128 | Brier Score: 0.2244
# Epoch:  21 | Loss: 0.07 | C-Index: 0.5143 | Brier Score: 0.2239
# Epoch:  22 | Loss: 0.05 | C-Index: 0.5161 | Brier Score: 0.2235
# Epoch:  23 | Loss: 0.04 | C-Index: 0.5184 | Brier Score: 0.2229
# Epoch:  24 | Loss: 0.02 | C-Index: 0.5181 | Brier Score: 0.2223
# Epoch:  25 | Loss: 0.01 | C-Index: 0.5209 | Brier Score: 0.2218
# Epoch:  26 | Loss: -0.00 | C-Index: 0.5245 | Brier Score: 0.2212
# Epoch:  27 | Loss: -0.01 | C-Index: 0.5258 | Brier Score: 0.2207
# Epoch:  28 | Loss: -0.02 | C-Index: 0.5282 | Brier Score: 0.2202
# Epoch:  29 | Loss: -0.04 | C-Index: 0.5301 | Brier Score: 0.2197
# Epoch:  30 | Loss: -0.05 | C-Index: 0.5324 | Brier Score: 0.2192
# Epoch:  31 | Loss: -0.06 | C-Index: 0.5361 | Brier Score: 0.2188
# Epoch:  32 | Loss: -0.07 | C-Index: 0.5375 | Brier Score: 0.2183
# Epoch:  33 | Loss: -0.08 | C-Index: 0.5389 | Brier Score: 0.2179
# Epoch:  34 | Loss: -0.09 | C-Index: 0.5401 | Brier Score: 0.2175
# Epoch:  35 | Loss: -0.10 | C-Index: 0.5425 | Brier Score: 0.2171
# Epoch:  36 | Loss: -0.10 | C-Index: 0.5439 | Brier Score: 0.2166
# Epoch:  37 | Loss: -0.11 | C-Index: 0.5459 | Brier Score: 0.2162
# Epoch:  38 | Loss: -0.12 | C-Index: 0.5478 | Brier Score: 0.2158
# Epoch:  39 | Loss: -0.13 | C-Index: 0.5490 | Brier Score: 0.2155
# Epoch:  40 | Loss: -0.14 | C-Index: 0.5503 | Brier Score: 0.2151
# Epoch:  41 | Loss: -0.15 | C-Index: 0.5528 | Brier Score: 0.2148
# Epoch:  42 | Loss: -0.15 | C-Index: 0.5535 | Brier Score: 0.2145
# Epoch:  43 | Loss: -0.16 | C-Index: 0.5553 | Brier Score: 0.2141
# Epoch:  44 | Loss: -0.17 | C-Index: 0.5578 | Brier Score: 0.2138
# Epoch:  45 | Loss: -0.18 | C-Index: 0.5600 | Brier Score: 0.2135
# Epoch:  46 | Loss: -0.18 | C-Index: 0.5625 | Brier Score: 0.2131
# Epoch:  47 | Loss: -0.19 | C-Index: 0.5646 | Brier Score: 0.2127
# Epoch:  48 | Loss: -0.20 | C-Index: 0.5659 | Brier Score: 0.2123
# Epoch:  49 | Loss: -0.20 | C-Index: 0.5678 | Brier Score: 0.2119
# Epoch:  50 | Loss: -0.21 | C-Index: 0.5684 | Brier Score: 0.2115
# Epoch:  51 | Loss: -0.22 | C-Index: 0.5697 | Brier Score: 0.2110
# Epoch:  52 | Loss: -0.22 | C-Index: 0.5715 | Brier Score: 0.2106
# Epoch:  53 | Loss: -0.23 | C-Index: 0.5745 | Brier Score: 0.2101
# Epoch:  54 | Loss: -0.23 | C-Index: 0.5770 | Brier Score: 0.2097
# Epoch:  55 | Loss: -0.24 | C-Index: 0.5796 | Brier Score: 0.2093
# Epoch:  56 | Loss: -0.24 | C-Index: 0.5829 | Brier Score: 0.2089
# Epoch:  57 | Loss: -0.25 | C-Index: 0.5848 | Brier Score: 0.2084
# Epoch:  58 | Loss: -0.25 | C-Index: 0.5880 | Brier Score: 0.2080
# Epoch:  59 | Loss: -0.26 | C-Index: 0.5910 | Brier Score: 0.2076
# Epoch:  60 | Loss: -0.26 | C-Index: 0.5917 | Brier Score: 0.2072
# Epoch:  61 | Loss: -0.27 | C-Index: 0.5935 | Brier Score: 0.2069
# Epoch:  62 | Loss: -0.27 | C-Index: 0.5961 | Brier Score: 0.2065
# Epoch:  63 | Loss: -0.28 | C-Index: 0.5972 | Brier Score: 0.2062
# Epoch:  64 | Loss: -0.28 | C-Index: 0.5989 | Brier Score: 0.2059
# Epoch:  65 | Loss: -0.29 | C-Index: 0.6012 | Brier Score: 0.2055
# Epoch:  66 | Loss: -0.29 | C-Index: 0.6038 | Brier Score: 0.2052
# Epoch:  67 | Loss: -0.30 | C-Index: 0.6051 | Brier Score: 0.2049
# Epoch:  68 | Loss: -0.30 | C-Index: 0.6069 | Brier Score: 0.2046
# Epoch:  69 | Loss: -0.31 | C-Index: 0.6075 | Brier Score: 0.2043
# Epoch:  70 | Loss: -0.31 | C-Index: 0.6084 | Brier Score: 0.2040
# Epoch:  71 | Loss: -0.31 | C-Index: 0.6113 | Brier Score: 0.2037
# Epoch:  72 | Loss: -0.32 | C-Index: 0.6134 | Brier Score: 0.2035
# Epoch:  73 | Loss: -0.32 | C-Index: 0.6149 | Brier Score: 0.2032
# Epoch:  74 | Loss: -0.33 | C-Index: 0.6168 | Brier Score: 0.2030
# Epoch:  75 | Loss: -0.33 | C-Index: 0.6181 | Brier Score: 0.2028
# Epoch:  76 | Loss: -0.33 | C-Index: 0.6203 | Brier Score: 0.2026
# Epoch:  77 | Loss: -0.34 | C-Index: 0.6211 | Brier Score: 0.2025
# Epoch:  78 | Loss: -0.34 | C-Index: 0.6214 | Brier Score: 0.2023
# Epoch:  79 | Loss: -0.34 | C-Index: 0.6219 | Brier Score: 0.2022
# Epoch:  80 | Loss: -0.35 | C-Index: 0.6224 | Brier Score: 0.2021
# Epoch:  81 | Loss: -0.35 | C-Index: 0.6233 | Brier Score: 0.2020
# Epoch:  82 | Loss: -0.35 | C-Index: 0.6225 | Brier Score: 0.2019
# Epoch:  83 | Loss: -0.36 | C-Index: 0.6231 | Brier Score: 0.2018
# Epoch:  84 | Loss: -0.36 | C-Index: 0.6244 | Brier Score: 0.2018
# Epoch:  85 | Loss: -0.36 | C-Index: 0.6247 | Brier Score: 0.2017
# Epoch:  86 | Loss: -0.37 | C-Index: 0.6262 | Brier Score: 0.2017
# Epoch:  87 | Loss: -0.37 | C-Index: 0.6267 | Brier Score: 0.2016
# Epoch:  88 | Loss: -0.37 | C-Index: 0.6283 | Brier Score: 0.2016
# Epoch:  89 | Loss: -0.38 | C-Index: 0.6302 | Brier Score: 0.2015
# Epoch:  90 | Loss: -0.38 | C-Index: 0.6298 | Brier Score: 0.2015
# Epoch:  91 | Loss: -0.38 | C-Index: 0.6299 | Brier Score: 0.2015
# Epoch:  92 | Loss: -0.38 | C-Index: 0.6301 | Brier Score: 0.2014
# Epoch:  93 | Loss: -0.39 | C-Index: 0.6306 | Brier Score: 0.2014
# Epoch:  94 | Loss: -0.39 | C-Index: 0.6311 | Brier Score: 0.2013
# Epoch:  95 | Loss: -0.39 | C-Index: 0.6308 | Brier Score: 0.2013
# Epoch:  96 | Loss: -0.39 | C-Index: 0.6311 | Brier Score: 0.2013
# Epoch:  97 | Loss: -0.40 | C-Index: 0.6318 | Brier Score: 0.2012
# Epoch:  98 | Loss: -0.40 | C-Index: 0.6321 | Brier Score: 0.2012
# Epoch:  99 | Loss: -0.40 | C-Index: 0.6334 | Brier Score: 0.2011
# Epoch: 100 | Loss: -0.41 | C-Index: 0.6339 | Brier Score: 0.2011
# Epoch: 101 | Loss: -0.41 | C-Index: 0.6345 | Brier Score: 0.2010
# Epoch: 102 | Loss: -0.41 | C-Index: 0.6357 | Brier Score: 0.2010
# Epoch: 103 | Loss: -0.41 | C-Index: 0.6351 | Brier Score: 0.2009
# Epoch: 104 | Loss: -0.41 | C-Index: 0.6351 | Brier Score: 0.2009
# Epoch: 105 | Loss: -0.42 | C-Index: 0.6355 | Brier Score: 0.2008
# Epoch: 106 | Loss: -0.42 | C-Index: 0.6359 | Brier Score: 0.2008
# Epoch: 107 | Loss: -0.42 | C-Index: 0.6367 | Brier Score: 0.2007
# Epoch: 108 | Loss: -0.42 | C-Index: 0.6368 | Brier Score: 0.2006
# Epoch: 109 | Loss: -0.43 | C-Index: 0.6377 | Brier Score: 0.2005
# Epoch: 110 | Loss: -0.43 | C-Index: 0.6383 | Brier Score: 0.2004
# Epoch: 111 | Loss: -0.43 | C-Index: 0.6385 | Brier Score: 0.2004
# Epoch: 112 | Loss: -0.43 | C-Index: 0.6389 | Brier Score: 0.2003
# Epoch: 113 | Loss: -0.43 | C-Index: 0.6389 | Brier Score: 0.2002
# Epoch: 114 | Loss: -0.44 | C-Index: 0.6395 | Brier Score: 0.2001
# Epoch: 115 | Loss: -0.44 | C-Index: 0.6399 | Brier Score: 0.2000
# Epoch: 116 | Loss: -0.44 | C-Index: 0.6405 | Brier Score: 0.2000
# Epoch: 117 | Loss: -0.44 | C-Index: 0.6407 | Brier Score: 0.1999
# Epoch: 118 | Loss: -0.44 | C-Index: 0.6411 | Brier Score: 0.1998
# Epoch: 119 | Loss: -0.45 | C-Index: 0.6413 | Brier Score: 0.1998
# Epoch: 120 | Loss: -0.45 | C-Index: 0.6414 | Brier Score: 0.1997
# Epoch: 121 | Loss: -0.45 | C-Index: 0.6413 | Brier Score: 0.1997
# Epoch: 122 | Loss: -0.45 | C-Index: 0.6413 | Brier Score: 0.1996
# Epoch: 123 | Loss: -0.45 | C-Index: 0.6417 | Brier Score: 0.1996
# Epoch: 124 | Loss: -0.46 | C-Index: 0.6421 | Brier Score: 0.1996
# Epoch: 125 | Loss: -0.46 | C-Index: 0.6418 | Brier Score: 0.1996
# Epoch: 126 | Loss: -0.46 | C-Index: 0.6413 | Brier Score: 0.1996
# Epoch: 127 | Loss: -0.46 | C-Index: 0.6417 | Brier Score: 0.1996
# Epoch: 128 | Loss: -0.46 | C-Index: 0.6417 | Brier Score: 0.1996
# Epoch: 129 | Loss: -0.47 | C-Index: 0.6414 | Brier Score: 0.1996
# Epoch: 130 | Loss: -0.47 | C-Index: 0.6417 | Brier Score: 0.1996
#
#
#
# ________________________________________________________________
# Split/Total Splits: 1/5
# Model             : Stratified Ranking Loss
# Hidden Layers     : [30 10]
#
#
# Epoch:   0 | Loss: 0.17 | C-Index: 0.5259 | Brier Score: 0.2436
# Epoch:   1 | Loss: 0.16 | C-Index: 0.5298 | Brier Score: 0.2423
# Epoch:   2 | Loss: 0.15 | C-Index: 0.5329 | Brier Score: 0.2409
# Epoch:   3 | Loss: 0.13 | C-Index: 0.5367 | Brier Score: 0.2396
# Epoch:   4 | Loss: 0.12 | C-Index: 0.5373 | Brier Score: 0.2382
# Epoch:   5 | Loss: 0.11 | C-Index: 0.5411 | Brier Score: 0.2368
# Epoch:   6 | Loss: 0.09 | C-Index: 0.5425 | Brier Score: 0.2355
# Epoch:   7 | Loss: 0.08 | C-Index: 0.5441 | Brier Score: 0.2342
# Epoch:   8 | Loss: 0.07 | C-Index: 0.5459 | Brier Score: 0.2328
# Epoch:   9 | Loss: 0.06 | C-Index: 0.5487 | Brier Score: 0.2315
# Epoch:  10 | Loss: 0.05 | C-Index: 0.5510 | Brier Score: 0.2302
# Epoch:  11 | Loss: 0.04 | C-Index: 0.5538 | Brier Score: 0.2289
# Epoch:  12 | Loss: 0.03 | C-Index: 0.5546 | Brier Score: 0.2276
# Epoch:  13 | Loss: 0.02 | C-Index: 0.5579 | Brier Score: 0.2263
# Epoch:  14 | Loss: 0.01 | C-Index: 0.5597 | Brier Score: 0.2251
# Epoch:  15 | Loss: -0.00 | C-Index: 0.5650 | Brier Score: 0.2239
# Epoch:  16 | Loss: -0.01 | C-Index: 0.5683 | Brier Score: 0.2227
# Epoch:  17 | Loss: -0.02 | C-Index: 0.5697 | Brier Score: 0.2216
# Epoch:  18 | Loss: -0.03 | C-Index: 0.5735 | Brier Score: 0.2206
# Epoch:  19 | Loss: -0.04 | C-Index: 0.5772 | Brier Score: 0.2196
# Epoch:  20 | Loss: -0.04 | C-Index: 0.5784 | Brier Score: 0.2186
# Epoch:  21 | Loss: -0.05 | C-Index: 0.5797 | Brier Score: 0.2176
# Epoch:  22 | Loss: -0.06 | C-Index: 0.5819 | Brier Score: 0.2166
# Epoch:  23 | Loss: -0.07 | C-Index: 0.5830 | Brier Score: 0.2156
# Epoch:  24 | Loss: -0.07 | C-Index: 0.5861 | Brier Score: 0.2146
# Epoch:  25 | Loss: -0.08 | C-Index: 0.5876 | Brier Score: 0.2137
# Epoch:  26 | Loss: -0.09 | C-Index: 0.5892 | Brier Score: 0.2128
# Epoch:  27 | Loss: -0.09 | C-Index: 0.5896 | Brier Score: 0.2119
# Epoch:  28 | Loss: -0.10 | C-Index: 0.5905 | Brier Score: 0.2111
# Epoch:  29 | Loss: -0.11 | C-Index: 0.5912 | Brier Score: 0.2103
# Epoch:  30 | Loss: -0.11 | C-Index: 0.5921 | Brier Score: 0.2095
# Epoch:  31 | Loss: -0.12 | C-Index: 0.5955 | Brier Score: 0.2088
# Epoch:  32 | Loss: -0.12 | C-Index: 0.5968 | Brier Score: 0.2081
# Epoch:  33 | Loss: -0.13 | C-Index: 0.5958 | Brier Score: 0.2074
# Epoch:  34 | Loss: -0.13 | C-Index: 0.5969 | Brier Score: 0.2067
# Epoch:  35 | Loss: -0.14 | C-Index: 0.5987 | Brier Score: 0.2061
# Epoch:  36 | Loss: -0.14 | C-Index: 0.5981 | Brier Score: 0.2054
# Epoch:  37 | Loss: -0.15 | C-Index: 0.5991 | Brier Score: 0.2048
# Epoch:  38 | Loss: -0.15 | C-Index: 0.5994 | Brier Score: 0.2043
# Epoch:  39 | Loss: -0.16 | C-Index: 0.6010 | Brier Score: 0.2038
# Epoch:  40 | Loss: -0.16 | C-Index: 0.6029 | Brier Score: 0.2033
# Epoch:  41 | Loss: -0.17 | C-Index: 0.6036 | Brier Score: 0.2028
# Epoch:  42 | Loss: -0.17 | C-Index: 0.6045 | Brier Score: 0.2023
# Epoch:  43 | Loss: -0.18 | C-Index: 0.6047 | Brier Score: 0.2020
# Epoch:  44 | Loss: -0.18 | C-Index: 0.6067 | Brier Score: 0.2016
# Epoch:  45 | Loss: -0.18 | C-Index: 0.6073 | Brier Score: 0.2013
# Epoch:  46 | Loss: -0.19 | C-Index: 0.6088 | Brier Score: 0.2010
# Epoch:  47 | Loss: -0.19 | C-Index: 0.6103 | Brier Score: 0.2008
# Epoch:  48 | Loss: -0.20 | C-Index: 0.6094 | Brier Score: 0.2005
# Epoch:  49 | Loss: -0.20 | C-Index: 0.6106 | Brier Score: 0.2003
# Epoch:  50 | Loss: -0.20 | C-Index: 0.6125 | Brier Score: 0.2001
# Epoch:  51 | Loss: -0.21 | C-Index: 0.6129 | Brier Score: 0.1999
# Epoch:  52 | Loss: -0.21 | C-Index: 0.6134 | Brier Score: 0.1998
# Epoch:  53 | Loss: -0.22 | C-Index: 0.6148 | Brier Score: 0.1996
# Epoch:  54 | Loss: -0.22 | C-Index: 0.6153 | Brier Score: 0.1994
# Epoch:  55 | Loss: -0.22 | C-Index: 0.6162 | Brier Score: 0.1993
# Epoch:  56 | Loss: -0.23 | C-Index: 0.6179 | Brier Score: 0.1992
# Epoch:  57 | Loss: -0.23 | C-Index: 0.6185 | Brier Score: 0.1991
# Epoch:  58 | Loss: -0.23 | C-Index: 0.6187 | Brier Score: 0.1990
# Epoch:  59 | Loss: -0.24 | C-Index: 0.6197 | Brier Score: 0.1989
# Epoch:  60 | Loss: -0.24 | C-Index: 0.6210 | Brier Score: 0.1988
# Epoch:  61 | Loss: -0.24 | C-Index: 0.6231 | Brier Score: 0.1987
# Epoch:  62 | Loss: -0.25 | C-Index: 0.6247 | Brier Score: 0.1986
# Epoch:  63 | Loss: -0.25 | C-Index: 0.6258 | Brier Score: 0.1985
# Epoch:  64 | Loss: -0.25 | C-Index: 0.6256 | Brier Score: 0.1985
# Epoch:  65 | Loss: -0.26 | C-Index: 0.6266 | Brier Score: 0.1984
# Epoch:  66 | Loss: -0.26 | C-Index: 0.6268 | Brier Score: 0.1983
# Epoch:  67 | Loss: -0.26 | C-Index: 0.6269 | Brier Score: 0.1983
# Epoch:  68 | Loss: -0.27 | C-Index: 0.6268 | Brier Score: 0.1982
# Epoch:  69 | Loss: -0.27 | C-Index: 0.6278 | Brier Score: 0.1982
# Epoch:  70 | Loss: -0.27 | C-Index: 0.6277 | Brier Score: 0.1981
# Epoch:  71 | Loss: -0.27 | C-Index: 0.6286 | Brier Score: 0.1980
# Epoch:  72 | Loss: -0.28 | C-Index: 0.6281 | Brier Score: 0.1980
# Epoch:  73 | Loss: -0.28 | C-Index: 0.6280 | Brier Score: 0.1979
# Epoch:  74 | Loss: -0.28 | C-Index: 0.6274 | Brier Score: 0.1978
# Epoch:  75 | Loss: -0.28 | C-Index: 0.6271 | Brier Score: 0.1977
# Epoch:  76 | Loss: -0.29 | C-Index: 0.6272 | Brier Score: 0.1976
# Epoch:  77 | Loss: -0.29 | C-Index: 0.6283 | Brier Score: 0.1976
# Epoch:  78 | Loss: -0.29 | C-Index: 0.6296 | Brier Score: 0.1975
# Epoch:  79 | Loss: -0.29 | C-Index: 0.6309 | Brier Score: 0.1975
# Epoch:  80 | Loss: -0.30 | C-Index: 0.6325 | Brier Score: 0.1974
# Epoch:  81 | Loss: -0.30 | C-Index: 0.6330 | Brier Score: 0.1973
# Epoch:  82 | Loss: -0.30 | C-Index: 0.6337 | Brier Score: 0.1973
# Epoch:  83 | Loss: -0.30 | C-Index: 0.6348 | Brier Score: 0.1972
# Epoch:  84 | Loss: -0.31 | C-Index: 0.6355 | Brier Score: 0.1972
# Epoch:  85 | Loss: -0.31 | C-Index: 0.6364 | Brier Score: 0.1972
# Epoch:  86 | Loss: -0.31 | C-Index: 0.6368 | Brier Score: 0.1971
# Epoch:  87 | Loss: -0.31 | C-Index: 0.6377 | Brier Score: 0.1971
# Epoch:  88 | Loss: -0.32 | C-Index: 0.6383 | Brier Score: 0.1970
# Epoch:  89 | Loss: -0.32 | C-Index: 0.6390 | Brier Score: 0.1970
# Epoch:  90 | Loss: -0.32 | C-Index: 0.6404 | Brier Score: 0.1970
# Epoch:  91 | Loss: -0.32 | C-Index: 0.6405 | Brier Score: 0.1969
# Epoch:  92 | Loss: -0.32 | C-Index: 0.6420 | Brier Score: 0.1969
# Epoch:  93 | Loss: -0.33 | C-Index: 0.6432 | Brier Score: 0.1969
# Epoch:  94 | Loss: -0.33 | C-Index: 0.6436 | Brier Score: 0.1969
# Epoch:  95 | Loss: -0.33 | C-Index: 0.6433 | Brier Score: 0.1969
# Epoch:  96 | Loss: -0.33 | C-Index: 0.6436 | Brier Score: 0.1969
#
#
#
# ________________________________________________________________
# Split/Total Splits: 2/5
# Model             : Partial Likelihood
# Hidden Layers     : [30 10]
#
#
# Epoch:   0 | Loss: 2589.44 | C-Index: 0.4397 | Brier Score: 0.2235
# Epoch:   1 | Loss: 2580.96 | C-Index: 0.4387 | Brier Score: 0.2226
# Epoch:   2 | Loss: 2572.85 | C-Index: 0.4388 | Brier Score: 0.2218
# Epoch:   3 | Loss: 2565.11 | C-Index: 0.4391 | Brier Score: 0.2210
# Epoch:   4 | Loss: 2557.62 | C-Index: 0.4391 | Brier Score: 0.2201
# Epoch:   5 | Loss: 2550.37 | C-Index: 0.4397 | Brier Score: 0.2192
# Epoch:   6 | Loss: 2543.39 | C-Index: 0.4401 | Brier Score: 0.2184
# Epoch:   7 | Loss: 2536.62 | C-Index: 0.4411 | Brier Score: 0.2175
# Epoch:   8 | Loss: 2530.06 | C-Index: 0.4424 | Brier Score: 0.2167
# Epoch:   9 | Loss: 2523.70 | C-Index: 0.4436 | Brier Score: 0.2159
# Epoch:  10 | Loss: 2517.50 | C-Index: 0.4438 | Brier Score: 0.2150
# Epoch:  11 | Loss: 2511.48 | C-Index: 0.4436 | Brier Score: 0.2141
# Epoch:  12 | Loss: 2505.60 | C-Index: 0.4436 | Brier Score: 0.2132
# Epoch:  13 | Loss: 2499.84 | C-Index: 0.4455 | Brier Score: 0.2123
# Epoch:  14 | Loss: 2494.28 | C-Index: 0.4473 | Brier Score: 0.2114
# Epoch:  15 | Loss: 2488.95 | C-Index: 0.4470 | Brier Score: 0.2106
# Epoch:  16 | Loss: 2483.82 | C-Index: 0.4494 | Brier Score: 0.2097
# Epoch:  17 | Loss: 2478.84 | C-Index: 0.4506 | Brier Score: 0.2088
# Epoch:  18 | Loss: 2473.99 | C-Index: 0.4540 | Brier Score: 0.2079
# Epoch:  19 | Loss: 2469.24 | C-Index: 0.4570 | Brier Score: 0.2071
# Epoch:  20 | Loss: 2464.54 | C-Index: 0.4587 | Brier Score: 0.2062
# Epoch:  21 | Loss: 2459.96 | C-Index: 0.4611 | Brier Score: 0.2054
# Epoch:  22 | Loss: 2455.51 | C-Index: 0.4646 | Brier Score: 0.2045
# Epoch:  23 | Loss: 2451.17 | C-Index: 0.4686 | Brier Score: 0.2037
# Epoch:  24 | Loss: 2446.93 | C-Index: 0.4725 | Brier Score: 0.2028
# Epoch:  25 | Loss: 2442.81 | C-Index: 0.4737 | Brier Score: 0.2020
# Epoch:  26 | Loss: 2438.77 | C-Index: 0.4771 | Brier Score: 0.2012
# Epoch:  27 | Loss: 2434.81 | C-Index: 0.4793 | Brier Score: 0.2004
# Epoch:  28 | Loss: 2430.93 | C-Index: 0.4812 | Brier Score: 0.1997
# Epoch:  29 | Loss: 2427.14 | C-Index: 0.4854 | Brier Score: 0.1989
# Epoch:  30 | Loss: 2423.41 | C-Index: 0.4894 | Brier Score: 0.1981
# Epoch:  31 | Loss: 2419.75 | C-Index: 0.4921 | Brier Score: 0.1974
# Epoch:  32 | Loss: 2416.17 | C-Index: 0.4967 | Brier Score: 0.1966
# Epoch:  33 | Loss: 2412.65 | C-Index: 0.5013 | Brier Score: 0.1959
# Epoch:  34 | Loss: 2409.19 | C-Index: 0.5057 | Brier Score: 0.1952
# Epoch:  35 | Loss: 2405.79 | C-Index: 0.5109 | Brier Score: 0.1944
# Epoch:  36 | Loss: 2402.44 | C-Index: 0.5147 | Brier Score: 0.1937
# Epoch:  37 | Loss: 2399.16 | C-Index: 0.5183 | Brier Score: 0.1930
# Epoch:  38 | Loss: 2395.94 | C-Index: 0.5212 | Brier Score: 0.1923
# Epoch:  39 | Loss: 2392.78 | C-Index: 0.5235 | Brier Score: 0.1916
# Epoch:  40 | Loss: 2389.65 | C-Index: 0.5278 | Brier Score: 0.1909
# Epoch:  41 | Loss: 2386.55 | C-Index: 0.5292 | Brier Score: 0.1902
# Epoch:  42 | Loss: 2383.50 | C-Index: 0.5330 | Brier Score: 0.1896
# Epoch:  43 | Loss: 2380.49 | C-Index: 0.5367 | Brier Score: 0.1889
# Epoch:  44 | Loss: 2377.52 | C-Index: 0.5415 | Brier Score: 0.1883
# Epoch:  45 | Loss: 2374.59 | C-Index: 0.5423 | Brier Score: 0.1877
# Epoch:  46 | Loss: 2371.72 | C-Index: 0.5459 | Brier Score: 0.1872
# Epoch:  47 | Loss: 2368.89 | C-Index: 0.5498 | Brier Score: 0.1866
# Epoch:  48 | Loss: 2366.10 | C-Index: 0.5540 | Brier Score: 0.1861
# Epoch:  49 | Loss: 2363.32 | C-Index: 0.5552 | Brier Score: 0.1855
# Epoch:  50 | Loss: 2360.57 | C-Index: 0.5575 | Brier Score: 0.1850
# Epoch:  51 | Loss: 2357.83 | C-Index: 0.5600 | Brier Score: 0.1844
# Epoch:  52 | Loss: 2355.15 | C-Index: 0.5617 | Brier Score: 0.1839
# Epoch:  53 | Loss: 2352.51 | C-Index: 0.5650 | Brier Score: 0.1834
# Epoch:  54 | Loss: 2349.90 | C-Index: 0.5667 | Brier Score: 0.1829
# Epoch:  55 | Loss: 2347.32 | C-Index: 0.5692 | Brier Score: 0.1824
# Epoch:  56 | Loss: 2344.78 | C-Index: 0.5718 | Brier Score: 0.1819
# Epoch:  57 | Loss: 2342.29 | C-Index: 0.5752 | Brier Score: 0.1814
# Epoch:  58 | Loss: 2339.82 | C-Index: 0.5787 | Brier Score: 0.1809
# Epoch:  59 | Loss: 2337.39 | C-Index: 0.5807 | Brier Score: 0.1805
# Epoch:  60 | Loss: 2335.00 | C-Index: 0.5831 | Brier Score: 0.1800
# Epoch:  61 | Loss: 2332.64 | C-Index: 0.5852 | Brier Score: 0.1796
# Epoch:  62 | Loss: 2330.30 | C-Index: 0.5872 | Brier Score: 0.1791
# Epoch:  63 | Loss: 2327.98 | C-Index: 0.5891 | Brier Score: 0.1787
# Epoch:  64 | Loss: 2325.70 | C-Index: 0.5911 | Brier Score: 0.1782
# Epoch:  65 | Loss: 2323.45 | C-Index: 0.5937 | Brier Score: 0.1778
# Epoch:  66 | Loss: 2321.23 | C-Index: 0.5953 | Brier Score: 0.1774
# Epoch:  67 | Loss: 2319.04 | C-Index: 0.5974 | Brier Score: 0.1770
# Epoch:  68 | Loss: 2316.88 | C-Index: 0.5986 | Brier Score: 0.1765
# Epoch:  69 | Loss: 2314.74 | C-Index: 0.5995 | Brier Score: 0.1761
# Epoch:  70 | Loss: 2312.61 | C-Index: 0.6007 | Brier Score: 0.1758
# Epoch:  71 | Loss: 2310.50 | C-Index: 0.6014 | Brier Score: 0.1754
# Epoch:  72 | Loss: 2308.42 | C-Index: 0.6027 | Brier Score: 0.1750
# Epoch:  73 | Loss: 2306.35 | C-Index: 0.6032 | Brier Score: 0.1746
# Epoch:  74 | Loss: 2304.32 | C-Index: 0.6054 | Brier Score: 0.1743
# Epoch:  75 | Loss: 2302.32 | C-Index: 0.6065 | Brier Score: 0.1739
# Epoch:  76 | Loss: 2300.34 | C-Index: 0.6076 | Brier Score: 0.1736
# Epoch:  77 | Loss: 2298.38 | C-Index: 0.6088 | Brier Score: 0.1732
# Epoch:  78 | Loss: 2296.45 | C-Index: 0.6097 | Brier Score: 0.1729
# Epoch:  79 | Loss: 2294.54 | C-Index: 0.6107 | Brier Score: 0.1726
# Epoch:  80 | Loss: 2292.65 | C-Index: 0.6119 | Brier Score: 0.1723
# Epoch:  81 | Loss: 2290.78 | C-Index: 0.6124 | Brier Score: 0.1720
# Epoch:  82 | Loss: 2288.93 | C-Index: 0.6137 | Brier Score: 0.1717
# Epoch:  83 | Loss: 2287.10 | C-Index: 0.6147 | Brier Score: 0.1714
# Epoch:  84 | Loss: 2285.28 | C-Index: 0.6161 | Brier Score: 0.1711
# Epoch:  85 | Loss: 2283.49 | C-Index: 0.6177 | Brier Score: 0.1708
# Epoch:  86 | Loss: 2281.72 | C-Index: 0.6194 | Brier Score: 0.1705
# Epoch:  87 | Loss: 2279.96 | C-Index: 0.6204 | Brier Score: 0.1703
# Epoch:  88 | Loss: 2278.21 | C-Index: 0.6215 | Brier Score: 0.1701
# Epoch:  89 | Loss: 2276.49 | C-Index: 0.6221 | Brier Score: 0.1698
# Epoch:  90 | Loss: 2274.77 | C-Index: 0.6232 | Brier Score: 0.1696
# Epoch:  91 | Loss: 2273.07 | C-Index: 0.6246 | Brier Score: 0.1694
# Epoch:  92 | Loss: 2271.38 | C-Index: 0.6263 | Brier Score: 0.1692
# Epoch:  93 | Loss: 2269.70 | C-Index: 0.6270 | Brier Score: 0.1690
# Epoch:  94 | Loss: 2268.04 | C-Index: 0.6286 | Brier Score: 0.1688
# Epoch:  95 | Loss: 2266.40 | C-Index: 0.6290 | Brier Score: 0.1686
# Epoch:  96 | Loss: 2264.77 | C-Index: 0.6307 | Brier Score: 0.1684
# Epoch:  97 | Loss: 2263.14 | C-Index: 0.6320 | Brier Score: 0.1683
# Epoch:  98 | Loss: 2261.52 | C-Index: 0.6332 | Brier Score: 0.1681
# Epoch:  99 | Loss: 2259.90 | C-Index: 0.6341 | Brier Score: 0.1679
# Epoch: 100 | Loss: 2258.29 | C-Index: 0.6345 | Brier Score: 0.1677
# Epoch: 101 | Loss: 2256.69 | C-Index: 0.6348 | Brier Score: 0.1675
# Epoch: 102 | Loss: 2255.11 | C-Index: 0.6347 | Brier Score: 0.1673
# Epoch: 103 | Loss: 2253.53 | C-Index: 0.6361 | Brier Score: 0.1672
# Epoch: 104 | Loss: 2251.96 | C-Index: 0.6361 | Brier Score: 0.1670
# Epoch: 105 | Loss: 2250.40 | C-Index: 0.6368 | Brier Score: 0.1668
# Epoch: 106 | Loss: 2248.86 | C-Index: 0.6378 | Brier Score: 0.1666
# Epoch: 107 | Loss: 2247.33 | C-Index: 0.6379 | Brier Score: 0.1665
# Epoch: 108 | Loss: 2245.81 | C-Index: 0.6385 | Brier Score: 0.1663
# Epoch: 109 | Loss: 2244.30 | C-Index: 0.6395 | Brier Score: 0.1661
# Epoch: 110 | Loss: 2242.80 | C-Index: 0.6400 | Brier Score: 0.1660
# Epoch: 111 | Loss: 2241.30 | C-Index: 0.6409 | Brier Score: 0.1658
# Epoch: 112 | Loss: 2239.81 | C-Index: 0.6417 | Brier Score: 0.1657
# Epoch: 113 | Loss: 2238.33 | C-Index: 0.6427 | Brier Score: 0.1655
# Epoch: 114 | Loss: 2236.86 | C-Index: 0.6434 | Brier Score: 0.1654
# Epoch: 115 | Loss: 2235.40 | C-Index: 0.6447 | Brier Score: 0.1653
# Epoch: 116 | Loss: 2233.95 | C-Index: 0.6456 | Brier Score: 0.1651
# Epoch: 117 | Loss: 2232.51 | C-Index: 0.6461 | Brier Score: 0.1650
# Epoch: 118 | Loss: 2231.09 | C-Index: 0.6473 | Brier Score: 0.1649
# Epoch: 119 | Loss: 2229.68 | C-Index: 0.6474 | Brier Score: 0.1648
# Epoch: 120 | Loss: 2228.27 | C-Index: 0.6483 | Brier Score: 0.1647
# Epoch: 121 | Loss: 2226.87 | C-Index: 0.6488 | Brier Score: 0.1646
# Epoch: 122 | Loss: 2225.48 | C-Index: 0.6490 | Brier Score: 0.1645
# Epoch: 123 | Loss: 2224.10 | C-Index: 0.6497 | Brier Score: 0.1644
# Epoch: 124 | Loss: 2222.73 | C-Index: 0.6502 | Brier Score: 0.1643
# Epoch: 125 | Loss: 2221.36 | C-Index: 0.6508 | Brier Score: 0.1642
# Epoch: 126 | Loss: 2220.00 | C-Index: 0.6518 | Brier Score: 0.1641
# Epoch: 127 | Loss: 2218.64 | C-Index: 0.6526 | Brier Score: 0.1640
# Epoch: 128 | Loss: 2217.29 | C-Index: 0.6536 | Brier Score: 0.1639
# Epoch: 129 | Loss: 2215.94 | C-Index: 0.6542 | Brier Score: 0.1638
# Epoch: 130 | Loss: 2214.60 | C-Index: 0.6543 | Brier Score: 0.1638
# Epoch: 131 | Loss: 2213.26 | C-Index: 0.6559 | Brier Score: 0.1637
# Epoch: 132 | Loss: 2211.94 | C-Index: 0.6569 | Brier Score: 0.1636
# Epoch: 133 | Loss: 2210.61 | C-Index: 0.6577 | Brier Score: 0.1635
# Epoch: 134 | Loss: 2209.28 | C-Index: 0.6586 | Brier Score: 0.1635
# Epoch: 135 | Loss: 2207.96 | C-Index: 0.6594 | Brier Score: 0.1634
# Epoch: 136 | Loss: 2206.65 | C-Index: 0.6592 | Brier Score: 0.1633
# Epoch: 137 | Loss: 2205.36 | C-Index: 0.6596 | Brier Score: 0.1632
# Epoch: 138 | Loss: 2204.07 | C-Index: 0.6611 | Brier Score: 0.1632
# Epoch: 139 | Loss: 2202.80 | C-Index: 0.6613 | Brier Score: 0.1631
# Epoch: 140 | Loss: 2201.53 | C-Index: 0.6620 | Brier Score: 0.1630
# Epoch: 141 | Loss: 2200.27 | C-Index: 0.6621 | Brier Score: 0.1630
# Epoch: 142 | Loss: 2199.02 | C-Index: 0.6627 | Brier Score: 0.1629
# Epoch: 143 | Loss: 2197.78 | C-Index: 0.6633 | Brier Score: 0.1629
# Epoch: 144 | Loss: 2196.54 | C-Index: 0.6636 | Brier Score: 0.1628
# Epoch: 145 | Loss: 2195.32 | C-Index: 0.6647 | Brier Score: 0.1628
# Epoch: 146 | Loss: 2194.10 | C-Index: 0.6648 | Brier Score: 0.1627
# Epoch: 147 | Loss: 2192.90 | C-Index: 0.6654 | Brier Score: 0.1627
# Epoch: 148 | Loss: 2191.71 | C-Index: 0.6662 | Brier Score: 0.1626
# Epoch: 149 | Loss: 2190.53 | C-Index: 0.6665 | Brier Score: 0.1626
# Epoch: 150 | Loss: 2189.35 | C-Index: 0.6671 | Brier Score: 0.1625
# Epoch: 151 | Loss: 2188.17 | C-Index: 0.6677 | Brier Score: 0.1625
# Epoch: 152 | Loss: 2187.01 | C-Index: 0.6681 | Brier Score: 0.1625
# Epoch: 153 | Loss: 2185.85 | C-Index: 0.6679 | Brier Score: 0.1624
# Epoch: 154 | Loss: 2184.70 | C-Index: 0.6688 | Brier Score: 0.1624
# Epoch: 155 | Loss: 2183.54 | C-Index: 0.6692 | Brier Score: 0.1623
# Epoch: 156 | Loss: 2182.39 | C-Index: 0.6691 | Brier Score: 0.1623
# Epoch: 157 | Loss: 2181.24 | C-Index: 0.6698 | Brier Score: 0.1622
# Epoch: 158 | Loss: 2180.09 | C-Index: 0.6706 | Brier Score: 0.1622
# Epoch: 159 | Loss: 2178.95 | C-Index: 0.6711 | Brier Score: 0.1621
# Epoch: 160 | Loss: 2177.82 | C-Index: 0.6716 | Brier Score: 0.1621
# Epoch: 161 | Loss: 2176.69 | C-Index: 0.6718 | Brier Score: 0.1621
# Epoch: 162 | Loss: 2175.57 | C-Index: 0.6730 | Brier Score: 0.1620
# Epoch: 163 | Loss: 2174.45 | C-Index: 0.6736 | Brier Score: 0.1620
# Epoch: 164 | Loss: 2173.32 | C-Index: 0.6739 | Brier Score: 0.1620
# Epoch: 165 | Loss: 2172.20 | C-Index: 0.6745 | Brier Score: 0.1620
# Epoch: 166 | Loss: 2171.07 | C-Index: 0.6753 | Brier Score: 0.1620
# Epoch: 167 | Loss: 2169.96 | C-Index: 0.6763 | Brier Score: 0.1619
# Epoch: 168 | Loss: 2168.85 | C-Index: 0.6770 | Brier Score: 0.1619
# Epoch: 169 | Loss: 2167.75 | C-Index: 0.6773 | Brier Score: 0.1619
# Epoch: 170 | Loss: 2166.64 | C-Index: 0.6777 | Brier Score: 0.1619
# Epoch: 171 | Loss: 2165.54 | C-Index: 0.6783 | Brier Score: 0.1619
# Epoch: 172 | Loss: 2164.44 | C-Index: 0.6787 | Brier Score: 0.1619
# Epoch: 173 | Loss: 2163.35 | C-Index: 0.6784 | Brier Score: 0.1619
#
#
#
# ________________________________________________________________
# Split/Total Splits: 2/5
# Model             : Stratified Partial Likelihood
# Hidden Layers     : [30 10]
#
#
# Epoch:   0 | Loss: 2086.35 | C-Index: 0.5817 | Brier Score: 0.1930
# Epoch:   1 | Loss: 2078.03 | C-Index: 0.5861 | Brier Score: 0.1925
# Epoch:   2 | Loss: 2070.11 | C-Index: 0.5918 | Brier Score: 0.1919
# Epoch:   3 | Loss: 2062.63 | C-Index: 0.5959 | Brier Score: 0.1914
# Epoch:   4 | Loss: 2055.50 | C-Index: 0.5988 | Brier Score: 0.1910
# Epoch:   5 | Loss: 2048.72 | C-Index: 0.6038 | Brier Score: 0.1905
# Epoch:   6 | Loss: 2042.30 | C-Index: 0.6096 | Brier Score: 0.1899
# Epoch:   7 | Loss: 2036.13 | C-Index: 0.6126 | Brier Score: 0.1894
# Epoch:   8 | Loss: 2030.33 | C-Index: 0.6160 | Brier Score: 0.1889
# Epoch:   9 | Loss: 2024.82 | C-Index: 0.6218 | Brier Score: 0.1883
# Epoch:  10 | Loss: 2019.51 | C-Index: 0.6265 | Brier Score: 0.1879
# Epoch:  11 | Loss: 2014.36 | C-Index: 0.6274 | Brier Score: 0.1874
# Epoch:  12 | Loss: 2009.37 | C-Index: 0.6331 | Brier Score: 0.1869
# Epoch:  13 | Loss: 2004.61 | C-Index: 0.6369 | Brier Score: 0.1863
# Epoch:  14 | Loss: 2000.09 | C-Index: 0.6399 | Brier Score: 0.1858
# Epoch:  15 | Loss: 1995.75 | C-Index: 0.6417 | Brier Score: 0.1853
# Epoch:  16 | Loss: 1991.53 | C-Index: 0.6448 | Brier Score: 0.1847
# Epoch:  17 | Loss: 1987.43 | C-Index: 0.6489 | Brier Score: 0.1842
# Epoch:  18 | Loss: 1983.41 | C-Index: 0.6519 | Brier Score: 0.1836
# Epoch:  19 | Loss: 1979.49 | C-Index: 0.6533 | Brier Score: 0.1829
# Epoch:  20 | Loss: 1975.68 | C-Index: 0.6563 | Brier Score: 0.1823
# Epoch:  21 | Loss: 1971.93 | C-Index: 0.6587 | Brier Score: 0.1816
# Epoch:  22 | Loss: 1968.27 | C-Index: 0.6597 | Brier Score: 0.1810
# Epoch:  23 | Loss: 1964.74 | C-Index: 0.6621 | Brier Score: 0.1803
# Epoch:  24 | Loss: 1961.32 | C-Index: 0.6652 | Brier Score: 0.1798
# Epoch:  25 | Loss: 1957.98 | C-Index: 0.6656 | Brier Score: 0.1793
# Epoch:  26 | Loss: 1954.70 | C-Index: 0.6669 | Brier Score: 0.1787
# Epoch:  27 | Loss: 1951.50 | C-Index: 0.6670 | Brier Score: 0.1782
# Epoch:  28 | Loss: 1948.40 | C-Index: 0.6668 | Brier Score: 0.1777
# Epoch:  29 | Loss: 1945.36 | C-Index: 0.6685 | Brier Score: 0.1771
# Epoch:  30 | Loss: 1942.36 | C-Index: 0.6700 | Brier Score: 0.1766
# Epoch:  31 | Loss: 1939.41 | C-Index: 0.6695 | Brier Score: 0.1760
# Epoch:  32 | Loss: 1936.52 | C-Index: 0.6703 | Brier Score: 0.1755
# Epoch:  33 | Loss: 1933.68 | C-Index: 0.6727 | Brier Score: 0.1749
# Epoch:  34 | Loss: 1930.92 | C-Index: 0.6748 | Brier Score: 0.1744
# Epoch:  35 | Loss: 1928.17 | C-Index: 0.6762 | Brier Score: 0.1739
# Epoch:  36 | Loss: 1925.46 | C-Index: 0.6775 | Brier Score: 0.1734
# Epoch:  37 | Loss: 1922.76 | C-Index: 0.6792 | Brier Score: 0.1729
# Epoch:  38 | Loss: 1920.11 | C-Index: 0.6804 | Brier Score: 0.1725
# Epoch:  39 | Loss: 1917.49 | C-Index: 0.6812 | Brier Score: 0.1721
# Epoch:  40 | Loss: 1914.92 | C-Index: 0.6822 | Brier Score: 0.1716
# Epoch:  41 | Loss: 1912.38 | C-Index: 0.6830 | Brier Score: 0.1712
# Epoch:  42 | Loss: 1909.89 | C-Index: 0.6835 | Brier Score: 0.1708
# Epoch:  43 | Loss: 1907.44 | C-Index: 0.6840 | Brier Score: 0.1704
# Epoch:  44 | Loss: 1905.03 | C-Index: 0.6847 | Brier Score: 0.1700
# Epoch:  45 | Loss: 1902.69 | C-Index: 0.6855 | Brier Score: 0.1696
# Epoch:  46 | Loss: 1900.39 | C-Index: 0.6855 | Brier Score: 0.1692
# Epoch:  47 | Loss: 1898.11 | C-Index: 0.6866 | Brier Score: 0.1688
# Epoch:  48 | Loss: 1895.90 | C-Index: 0.6884 | Brier Score: 0.1684
# Epoch:  49 | Loss: 1893.71 | C-Index: 0.6887 | Brier Score: 0.1681
# Epoch:  50 | Loss: 1891.55 | C-Index: 0.6893 | Brier Score: 0.1677
# Epoch:  51 | Loss: 1889.43 | C-Index: 0.6911 | Brier Score: 0.1674
# Epoch:  52 | Loss: 1887.32 | C-Index: 0.6915 | Brier Score: 0.1670
# Epoch:  53 | Loss: 1885.23 | C-Index: 0.6918 | Brier Score: 0.1667
# Epoch:  54 | Loss: 1883.16 | C-Index: 0.6925 | Brier Score: 0.1664
# Epoch:  55 | Loss: 1881.12 | C-Index: 0.6938 | Brier Score: 0.1661
# Epoch:  56 | Loss: 1879.10 | C-Index: 0.6944 | Brier Score: 0.1658
# Epoch:  57 | Loss: 1877.12 | C-Index: 0.6955 | Brier Score: 0.1655
# Epoch:  58 | Loss: 1875.17 | C-Index: 0.6974 | Brier Score: 0.1653
# Epoch:  59 | Loss: 1873.24 | C-Index: 0.6985 | Brier Score: 0.1650
# Epoch:  60 | Loss: 1871.33 | C-Index: 0.7000 | Brier Score: 0.1648
# Epoch:  61 | Loss: 1869.45 | C-Index: 0.7008 | Brier Score: 0.1646
# Epoch:  62 | Loss: 1867.60 | C-Index: 0.7012 | Brier Score: 0.1643
# Epoch:  63 | Loss: 1865.76 | C-Index: 0.7020 | Brier Score: 0.1641
# Epoch:  64 | Loss: 1863.96 | C-Index: 0.7023 | Brier Score: 0.1639
# Epoch:  65 | Loss: 1862.18 | C-Index: 0.7037 | Brier Score: 0.1638
# Epoch:  66 | Loss: 1860.41 | C-Index: 0.7050 | Brier Score: 0.1636
# Epoch:  67 | Loss: 1858.67 | C-Index: 0.7046 | Brier Score: 0.1634
# Epoch:  68 | Loss: 1856.93 | C-Index: 0.7036 | Brier Score: 0.1632
# Epoch:  69 | Loss: 1855.21 | C-Index: 0.7039 | Brier Score: 0.1631
# Epoch:  70 | Loss: 1853.53 | C-Index: 0.7034 | Brier Score: 0.1629
# Epoch:  71 | Loss: 1851.86 | C-Index: 0.7044 | Brier Score: 0.1628
# Epoch:  72 | Loss: 1850.21 | C-Index: 0.7049 | Brier Score: 0.1626
# Epoch:  73 | Loss: 1848.57 | C-Index: 0.7049 | Brier Score: 0.1624
# Epoch:  74 | Loss: 1846.94 | C-Index: 0.7054 | Brier Score: 0.1623
# Epoch:  75 | Loss: 1845.32 | C-Index: 0.7066 | Brier Score: 0.1621
# Epoch:  76 | Loss: 1843.69 | C-Index: 0.7068 | Brier Score: 0.1619
# Epoch:  77 | Loss: 1842.08 | C-Index: 0.7075 | Brier Score: 0.1617
# Epoch:  78 | Loss: 1840.48 | C-Index: 0.7081 | Brier Score: 0.1616
# Epoch:  79 | Loss: 1838.88 | C-Index: 0.7083 | Brier Score: 0.1614
# Epoch:  80 | Loss: 1837.31 | C-Index: 0.7088 | Brier Score: 0.1613
# Epoch:  81 | Loss: 1835.76 | C-Index: 0.7097 | Brier Score: 0.1611
# Epoch:  82 | Loss: 1834.22 | C-Index: 0.7105 | Brier Score: 0.1610
# Epoch:  83 | Loss: 1832.69 | C-Index: 0.7108 | Brier Score: 0.1608
# Epoch:  84 | Loss: 1831.17 | C-Index: 0.7111 | Brier Score: 0.1607
# Epoch:  85 | Loss: 1829.66 | C-Index: 0.7118 | Brier Score: 0.1605
# Epoch:  86 | Loss: 1828.16 | C-Index: 0.7125 | Brier Score: 0.1604
# Epoch:  87 | Loss: 1826.66 | C-Index: 0.7131 | Brier Score: 0.1603
# Epoch:  88 | Loss: 1825.18 | C-Index: 0.7131 | Brier Score: 0.1602
# Epoch:  89 | Loss: 1823.72 | C-Index: 0.7134 | Brier Score: 0.1601
# Epoch:  90 | Loss: 1822.26 | C-Index: 0.7139 | Brier Score: 0.1599
# Epoch:  91 | Loss: 1820.77 | C-Index: 0.7142 | Brier Score: 0.1598
# Epoch:  92 | Loss: 1819.30 | C-Index: 0.7148 | Brier Score: 0.1596
# Epoch:  93 | Loss: 1817.84 | C-Index: 0.7155 | Brier Score: 0.1595
# Epoch:  94 | Loss: 1816.38 | C-Index: 0.7155 | Brier Score: 0.1594
# Epoch:  95 | Loss: 1814.92 | C-Index: 0.7153 | Brier Score: 0.1593
# Epoch:  96 | Loss: 1813.46 | C-Index: 0.7156 | Brier Score: 0.1591
# Epoch:  97 | Loss: 1812.02 | C-Index: 0.7154 | Brier Score: 0.1590
# Epoch:  98 | Loss: 1810.60 | C-Index: 0.7156 | Brier Score: 0.1589
# Epoch:  99 | Loss: 1809.18 | C-Index: 0.7154 | Brier Score: 0.1589
# Epoch: 100 | Loss: 1807.77 | C-Index: 0.7150 | Brier Score: 0.1588
# Epoch: 101 | Loss: 1806.36 | C-Index: 0.7149 | Brier Score: 0.1587
# Epoch: 102 | Loss: 1804.98 | C-Index: 0.7153 | Brier Score: 0.1586
# Epoch: 103 | Loss: 1803.60 | C-Index: 0.7156 | Brier Score: 0.1586
# ...
# Epoch:  66 | Loss: -0.31 | C-Index: 0.6921 | Brier Score: 0.1577
# Epoch:  67 | Loss: -0.31 | C-Index: 0.6926 | Brier Score: 0.1574
# Epoch:  68 | Loss: -0.31 | C-Index: 0.6948 | Brier Score: 0.1571
# Epoch:  69 | Loss: -0.32 | C-Index: 0.6956 | Brier Score: 0.1568
# Epoch:  70 | Loss: -0.32 | C-Index: 0.6962 | Brier Score: 0.1565
# Epoch:  71 | Loss: -0.32 | C-Index: 0.6967 | Brier Score: 0.1562
# Epoch:  72 | Loss: -0.32 | C-Index: 0.6978 | Brier Score: 0.1559
# Epoch:  73 | Loss: -0.33 | C-Index: 0.6992 | Brier Score: 0.1556
# Epoch:  74 | Loss: -0.33 | C-Index: 0.7008 | Brier Score: 0.1553
# Epoch:  75 | Loss: -0.33 | C-Index: 0.7014 | Brier Score: 0.1550
# Epoch:  76 | Loss: -0.33 | C-Index: 0.7026 | Brier Score: 0.1547
# Epoch:  77 | Loss: -0.34 | C-Index: 0.7037 | Brier Score: 0.1545
# Epoch:  78 | Loss: -0.34 | C-Index: 0.7050 | Brier Score: 0.1542
# Epoch:  79 | Loss: -0.34 | C-Index: 0.7061 | Brier Score: 0.1539
# Epoch:  80 | Loss: -0.34 | C-Index: 0.7067 | Brier Score: 0.1537
# Epoch:  81 | Loss: -0.35 | C-Index: 0.7087 | Brier Score: 0.1534
# Epoch:  82 | Loss: -0.35 | C-Index: 0.7092 | Brier Score: 0.1532
# Epoch:  83 | Loss: -0.35 | C-Index: 0.7101 | Brier Score: 0.1530
# Epoch:  84 | Loss: -0.35 | C-Index: 0.7100 | Brier Score: 0.1528
# Epoch:  85 | Loss: -0.35 | C-Index: 0.7114 | Brier Score: 0.1526
# Epoch:  86 | Loss: -0.36 | C-Index: 0.7119 | Brier Score: 0.1524
# Epoch:  87 | Loss: -0.36 | C-Index: 0.7120 | Brier Score: 0.1522
# Epoch:  88 | Loss: -0.36 | C-Index: 0.7123 | Brier Score: 0.1521
# Epoch:  89 | Loss: -0.36 | C-Index: 0.7123 | Brier Score: 0.1519
# Epoch:  90 | Loss: -0.37 | C-Index: 0.7136 | Brier Score: 0.1518
# Epoch:  91 | Loss: -0.37 | C-Index: 0.7134 | Brier Score: 0.1516
# Epoch:  92 | Loss: -0.37 | C-Index: 0.7141 | Brier Score: 0.1515
# Epoch:  93 | Loss: -0.37 | C-Index: 0.7150 | Brier Score: 0.1513
# Epoch:  94 | Loss: -0.37 | C-Index: 0.7153 | Brier Score: 0.1512
# Epoch:  95 | Loss: -0.38 | C-Index: 0.7167 | Brier Score: 0.1511
# Epoch:  96 | Loss: -0.38 | C-Index: 0.7172 | Brier Score: 0.1509
# Epoch:  97 | Loss: -0.38 | C-Index: 0.7177 | Brier Score: 0.1508
# Epoch:  98 | Loss: -0.38 | C-Index: 0.7181 | Brier Score: 0.1507
# Epoch:  99 | Loss: -0.38 | C-Index: 0.7192 | Brier Score: 0.1506
# Epoch: 100 | Loss: -0.39 | C-Index: 0.7195 | Brier Score: 0.1505
# Epoch: 101 | Loss: -0.39 | C-Index: 0.7195 | Brier Score: 0.1504
# Epoch: 102 | Loss: -0.39 | C-Index: 0.7199 | Brier Score: 0.1503
# Epoch: 103 | Loss: -0.39 | C-Index: 0.7202 | Brier Score: 0.1502
# Epoch: 104 | Loss: -0.39 | C-Index: 0.7202 | Brier Score: 0.1501
# Epoch: 105 | Loss: -0.39 | C-Index: 0.7206 | Brier Score: 0.1500
# Epoch: 106 | Loss: -0.40 | C-Index: 0.7206 | Brier Score: 0.1499
# Epoch: 107 | Loss: -0.40 | C-Index: 0.7205 | Brier Score: 0.1498
# Epoch: 108 | Loss: -0.40 | C-Index: 0.7217 | Brier Score: 0.1497
# Epoch: 109 | Loss: -0.40 | C-Index: 0.7222 | Brier Score: 0.1497
# Epoch: 110 | Loss: -0.40 | C-Index: 0.7228 | Brier Score: 0.1496
# Epoch: 111 | Loss: -0.40 | C-Index: 0.7238 | Brier Score: 0.1496
# Epoch: 112 | Loss: -0.41 | C-Index: 0.7244 | Brier Score: 0.1495
# Epoch: 113 | Loss: -0.41 | C-Index: 0.7249 | Brier Score: 0.1495
# Epoch: 114 | Loss: -0.41 | C-Index: 0.7250 | Brier Score: 0.1495
# Epoch: 115 | Loss: -0.41 | C-Index: 0.7252 | Brier Score: 0.1494
# Epoch: 116 | Loss: -0.41 | C-Index: 0.7260 | Brier Score: 0.1494
# Epoch: 117 | Loss: -0.41 | C-Index: 0.7263 | Brier Score: 0.1493
# Epoch: 118 | Loss: -0.42 | C-Index: 0.7264 | Brier Score: 0.1493
# Epoch: 119 | Loss: -0.42 | C-Index: 0.7269 | Brier Score: 0.1493
# Epoch: 120 | Loss: -0.42 | C-Index: 0.7269 | Brier Score: 0.1492
# Epoch: 121 | Loss: -0.42 | C-Index: 0.7278 | Brier Score: 0.1492
# Epoch: 122 | Loss: -0.42 | C-Index: 0.7282 | Brier Score: 0.1491
# Epoch: 123 | Loss: -0.42 | C-Index: 0.7291 | Brier Score: 0.1491
# Epoch: 124 | Loss: -0.42 | C-Index: 0.7300 | Brier Score: 0.1491
# Epoch: 125 | Loss: -0.43 | C-Index: 0.7305 | Brier Score: 0.1490
# Epoch: 126 | Loss: -0.43 | C-Index: 0.7308 | Brier Score: 0.1490
# Epoch: 127 | Loss: -0.43 | C-Index: 0.7311 | Brier Score: 0.1489
# Epoch: 128 | Loss: -0.43 | C-Index: 0.7318 | Brier Score: 0.1489
# Epoch: 129 | Loss: -0.43 | C-Index: 0.7330 | Brier Score: 0.1488
# Epoch: 130 | Loss: -0.43 | C-Index: 0.7335 | Brier Score: 0.1488
# Epoch: 131 | Loss: -0.43 | C-Index: 0.7344 | Brier Score: 0.1487
# Epoch: 132 | Loss: -0.44 | C-Index: 0.7346 | Brier Score: 0.1487
# Epoch: 133 | Loss: -0.44 | C-Index: 0.7347 | Brier Score: 0.1486
# Epoch: 134 | Loss: -0.44 | C-Index: 0.7344 | Brier Score: 0.1486
# Epoch: 135 | Loss: -0.44 | C-Index: 0.7349 | Brier Score: 0.1486
# Epoch: 136 | Loss: -0.44 | C-Index: 0.7349 | Brier Score: 0.1485
# Epoch: 137 | Loss: -0.44 | C-Index: 0.7347 | Brier Score: 0.1485
# Epoch: 138 | Loss: -0.44 | C-Index: 0.7344 | Brier Score: 0.1485
# Epoch: 139 | Loss: -0.45 | C-Index: 0.7346 | Brier Score: 0.1484
# Epoch: 140 | Loss: -0.45 | C-Index: 0.7346 | Brier Score: 0.1484
# Epoch: 141 | Loss: -0.45 | C-Index: 0.7344 | Brier Score: 0.1484
# Epoch: 142 | Loss: -0.45 | C-Index: 0.7346 | Brier Score: 0.1484
# Epoch: 143 | Loss: -0.45 | C-Index: 0.7346 | Brier Score: 0.1483
# Epoch: 144 | Loss: -0.45 | C-Index: 0.7343 | Brier Score: 0.1483
# Epoch: 145 | Loss: -0.45 | C-Index: 0.7343 | Brier Score: 0.1483
# Epoch: 146 | Loss: -0.46 | C-Index: 0.7347 | Brier Score: 0.1482
# Epoch: 147 | Loss: -0.46 | C-Index: 0.7354 | Brier Score: 0.1482
# Epoch: 148 | Loss: -0.46 | C-Index: 0.7357 | Brier Score: 0.1481
# Epoch: 149 | Loss: -0.46 | C-Index: 0.7357 | Brier Score: 0.1481
# Epoch: 150 | Loss: -0.46 | C-Index: 0.7358 | Brier Score: 0.1481
# Epoch: 151 | Loss: -0.46 | C-Index: 0.7365 | Brier Score: 0.1480
# Epoch: 152 | Loss: -0.46 | C-Index: 0.7363 | Brier Score: 0.1479
# Epoch: 153 | Loss: -0.46 | C-Index: 0.7371 | Brier Score: 0.1479
# Epoch: 154 | Loss: -0.47 | C-Index: 0.7372 | Brier Score: 0.1478
# Epoch: 155 | Loss: -0.47 | C-Index: 0.7377 | Brier Score: 0.1478
# Epoch: 156 | Loss: -0.47 | C-Index: 0.7382 | Brier Score: 0.1477
# Epoch: 157 | Loss: -0.47 | C-Index: 0.7385 | Brier Score: 0.1477
# Epoch: 158 | Loss: -0.47 | C-Index: 0.7383 | Brier Score: 0.1476
# Epoch: 159 | Loss: -0.47 | C-Index: 0.7386 | Brier Score: 0.1476
# Epoch: 160 | Loss: -0.47 | C-Index: 0.7386 | Brier Score: 0.1475
# Epoch: 161 | Loss: -0.47 | C-Index: 0.7388 | Brier Score: 0.1475
# Epoch: 162 | Loss: -0.48 | C-Index: 0.7394 | Brier Score: 0.1474
# Epoch: 163 | Loss: -0.48 | C-Index: 0.7401 | Brier Score: 0.1473
# Epoch: 164 | Loss: -0.48 | C-Index: 0.7405 | Brier Score: 0.1473
# Epoch: 165 | Loss: -0.48 | C-Index: 0.7405 | Brier Score: 0.1472
# Epoch: 166 | Loss: -0.48 | C-Index: 0.7404 | Brier Score: 0.1472
# Epoch: 167 | Loss: -0.48 | C-Index: 0.7405 | Brier Score: 0.1472
# Epoch: 168 | Loss: -0.48 | C-Index: 0.7413 | Brier Score: 0.1471
# Epoch: 169 | Loss: -0.48 | C-Index: 0.7415 | Brier Score: 0.1471
# Epoch: 170 | Loss: -0.48 | C-Index: 0.7424 | Brier Score: 0.1470
# Epoch: 171 | Loss: -0.49 | C-Index: 0.7426 | Brier Score: 0.1469
# Epoch: 172 | Loss: -0.49 | C-Index: 0.7430 | Brier Score: 0.1469
# Epoch: 173 | Loss: -0.49 | C-Index: 0.7437 | Brier Score: 0.1468
# Epoch: 174 | Loss: -0.49 | C-Index: 0.7433 | Brier Score: 0.1468
# Epoch: 175 | Loss: -0.49 | C-Index: 0.7438 | Brier Score: 0.1467
# Epoch: 176 | Loss: -0.49 | C-Index: 0.7441 | Brier Score: 0.1466
# Epoch: 177 | Loss: -0.49 | C-Index: 0.7443 | Brier Score: 0.1465
# Epoch: 178 | Loss: -0.49 | C-Index: 0.7441 | Brier Score: 0.1465
# Epoch: 179 | Loss: -0.49 | C-Index: 0.7440 | Brier Score: 0.1464
# Epoch: 180 | Loss: -0.50 | C-Index: 0.7446 | Brier Score: 0.1464
# Epoch: 181 | Loss: -0.50 | C-Index: 0.7448 | Brier Score: 0.1463
# Epoch: 182 | Loss: -0.50 | C-Index: 0.7454 | Brier Score: 0.1462
# Epoch: 183 | Loss: -0.50 | C-Index: 0.7454 | Brier Score: 0.1462
# Epoch: 184 | Loss: -0.50 | C-Index: 0.7463 | Brier Score: 0.1461
# Epoch: 185 | Loss: -0.50 | C-Index: 0.7463 | Brier Score: 0.1461
# Epoch: 186 | Loss: -0.50 | C-Index: 0.7468 | Brier Score: 0.1460
# Epoch: 187 | Loss: -0.50 | C-Index: 0.7466 | Brier Score: 0.1460
# Epoch: 188 | Loss: -0.50 | C-Index: 0.7466 | Brier Score: 0.1459
# Epoch: 189 | Loss: -0.51 | C-Index: 0.7474 | Brier Score: 0.1459
# Epoch: 190 | Loss: -0.51 | C-Index: 0.7473 | Brier Score: 0.1459
# Epoch: 191 | Loss: -0.51 | C-Index: 0.7477 | Brier Score: 0.1458
# Epoch: 192 | Loss: -0.51 | C-Index: 0.7476 | Brier Score: 0.1458
# Epoch: 193 | Loss: -0.51 | C-Index: 0.7479 | Brier Score: 0.1458
# Epoch: 194 | Loss: -0.51 | C-Index: 0.7482 | Brier Score: 0.1457
# Epoch: 195 | Loss: -0.51 | C-Index: 0.7485 | Brier Score: 0.1457
# Epoch: 196 | Loss: -0.51 | C-Index: 0.7488 | Brier Score: 0.1457
# Epoch: 197 | Loss: -0.51 | C-Index: 0.7485 | Brier Score: 0.1457
# Epoch: 198 | Loss: -0.51 | C-Index: 0.7487 | Brier Score: 0.1456
#
#
#
# ________________________________________________________________
# Split/Total Splits: 5/5
# Model             : Stratified Ranking Loss
# Hidden Layers     : [30 10]
#
#
# Epoch:   0 | Loss: 0.09 | C-Index: 0.4494 | Brier Score: 0.1958
# Epoch:   1 | Loss: 0.08 | C-Index: 0.4582 | Brier Score: 0.1945
# Epoch:   2 | Loss: 0.07 | C-Index: 0.4660 | Brier Score: 0.1932
# Epoch:   3 | Loss: 0.06 | C-Index: 0.4743 | Brier Score: 0.1917
# Epoch:   4 | Loss: 0.05 | C-Index: 0.4831 | Brier Score: 0.1903
# Epoch:   5 | Loss: 0.04 | C-Index: 0.4903 | Brier Score: 0.1889
# Epoch:   6 | Loss: 0.03 | C-Index: 0.4975 | Brier Score: 0.1875
# Epoch:   7 | Loss: 0.03 | C-Index: 0.5036 | Brier Score: 0.1861
# Epoch:   8 | Loss: 0.02 | C-Index: 0.5099 | Brier Score: 0.1847
# Epoch:   9 | Loss: 0.01 | C-Index: 0.5161 | Brier Score: 0.1833
# Epoch:  10 | Loss: -0.00 | C-Index: 0.5240 | Brier Score: 0.1819
# Epoch:  11 | Loss: -0.01 | C-Index: 0.5302 | Brier Score: 0.1805
# Epoch:  12 | Loss: -0.02 | C-Index: 0.5377 | Brier Score: 0.1792
# Epoch:  13 | Loss: -0.02 | C-Index: 0.5459 | Brier Score: 0.1779
# Epoch:  14 | Loss: -0.03 | C-Index: 0.5521 | Brier Score: 0.1766
# Epoch:  15 | Loss: -0.04 | C-Index: 0.5590 | Brier Score: 0.1754
# Epoch:  16 | Loss: -0.05 | C-Index: 0.5670 | Brier Score: 0.1743
# Epoch:  17 | Loss: -0.06 | C-Index: 0.5714 | Brier Score: 0.1732
# Epoch:  18 | Loss: -0.06 | C-Index: 0.5767 | Brier Score: 0.1721
# Epoch:  19 | Loss: -0.07 | C-Index: 0.5816 | Brier Score: 0.1711
# Epoch:  20 | Loss: -0.08 | C-Index: 0.5900 | Brier Score: 0.1701
# Epoch:  21 | Loss: -0.08 | C-Index: 0.5952 | Brier Score: 0.1691
# Epoch:  22 | Loss: -0.09 | C-Index: 0.5996 | Brier Score: 0.1682
# Epoch:  23 | Loss: -0.10 | C-Index: 0.6043 | Brier Score: 0.1672
# Epoch:  24 | Loss: -0.10 | C-Index: 0.6079 | Brier Score: 0.1663
# Epoch:  25 | Loss: -0.11 | C-Index: 0.6121 | Brier Score: 0.1655
# Epoch:  26 | Loss: -0.11 | C-Index: 0.6156 | Brier Score: 0.1646
# Epoch:  27 | Loss: -0.12 | C-Index: 0.6192 | Brier Score: 0.1638
# Epoch:  28 | Loss: -0.13 | C-Index: 0.6229 | Brier Score: 0.1630
# Epoch:  29 | Loss: -0.13 | C-Index: 0.6239 | Brier Score: 0.1622
# Epoch:  30 | Loss: -0.14 | C-Index: 0.6273 | Brier Score: 0.1614
# Epoch:  31 | Loss: -0.14 | C-Index: 0.6303 | Brier Score: 0.1606
# Epoch:  32 | Loss: -0.15 | C-Index: 0.6329 | Brier Score: 0.1599
# Epoch:  33 | Loss: -0.15 | C-Index: 0.6350 | Brier Score: 0.1593
# Epoch:  34 | Loss: -0.16 | C-Index: 0.6376 | Brier Score: 0.1588
# Epoch:  35 | Loss: -0.16 | C-Index: 0.6397 | Brier Score: 0.1582
# Epoch:  36 | Loss: -0.17 | C-Index: 0.6423 | Brier Score: 0.1577
# Epoch:  37 | Loss: -0.17 | C-Index: 0.6452 | Brier Score: 0.1572
# Epoch:  38 | Loss: -0.18 | C-Index: 0.6466 | Brier Score: 0.1568
# Epoch:  39 | Loss: -0.18 | C-Index: 0.6481 | Brier Score: 0.1563
# Epoch:  40 | Loss: -0.19 | C-Index: 0.6506 | Brier Score: 0.1558
# Epoch:  41 | Loss: -0.19 | C-Index: 0.6527 | Brier Score: 0.1554
# Epoch:  42 | Loss: -0.20 | C-Index: 0.6547 | Brier Score: 0.1549
# Epoch:  43 | Loss: -0.20 | C-Index: 0.6557 | Brier Score: 0.1545
# Epoch:  44 | Loss: -0.20 | C-Index: 0.6577 | Brier Score: 0.1540
# Epoch:  45 | Loss: -0.21 | C-Index: 0.6594 | Brier Score: 0.1536
# Epoch:  46 | Loss: -0.21 | C-Index: 0.6622 | Brier Score: 0.1532
# Epoch:  47 | Loss: -0.22 | C-Index: 0.6646 | Brier Score: 0.1528
# Epoch:  48 | Loss: -0.22 | C-Index: 0.6650 | Brier Score: 0.1525
# Epoch:  49 | Loss: -0.22 | C-Index: 0.6663 | Brier Score: 0.1521
# Epoch:  50 | Loss: -0.23 | C-Index: 0.6669 | Brier Score: 0.1518
# Epoch:  51 | Loss: -0.23 | C-Index: 0.6685 | Brier Score: 0.1515
# Epoch:  52 | Loss: -0.24 | C-Index: 0.6696 | Brier Score: 0.1512
# Epoch:  53 | Loss: -0.24 | C-Index: 0.6699 | Brier Score: 0.1509
# Epoch:  54 | Loss: -0.24 | C-Index: 0.6712 | Brier Score: 0.1506
# Epoch:  55 | Loss: -0.25 | C-Index: 0.6723 | Brier Score: 0.1504
# Epoch:  56 | Loss: -0.25 | C-Index: 0.6735 | Brier Score: 0.1502
# Epoch:  57 | Loss: -0.25 | C-Index: 0.6743 | Brier Score: 0.1500
# Epoch:  58 | Loss: -0.26 | C-Index: 0.6754 | Brier Score: 0.1498
# Epoch:  59 | Loss: -0.26 | C-Index: 0.6754 | Brier Score: 0.1496
# Epoch:  60 | Loss: -0.26 | C-Index: 0.6762 | Brier Score: 0.1494
# Epoch:  61 | Loss: -0.27 | C-Index: 0.6768 | Brier Score: 0.1492
# Epoch:  62 | Loss: -0.27 | C-Index: 0.6780 | Brier Score: 0.1490
# Epoch:  63 | Loss: -0.27 | C-Index: 0.6793 | Brier Score: 0.1489
# Epoch:  64 | Loss: -0.27 | C-Index: 0.6813 | Brier Score: 0.1487
# Epoch:  65 | Loss: -0.28 | C-Index: 0.6831 | Brier Score: 0.1485
# Epoch:  66 | Loss: -0.28 | C-Index: 0.6849 | Brier Score: 0.1484
# Epoch:  67 | Loss: -0.28 | C-Index: 0.6860 | Brier Score: 0.1483
# Epoch:  68 | Loss: -0.29 | C-Index: 0.6863 | Brier Score: 0.1482
# Epoch:  69 | Loss: -0.29 | C-Index: 0.6874 | Brier Score: 0.1480
# Epoch:  70 | Loss: -0.29 | C-Index: 0.6891 | Brier Score: 0.1479
# Epoch:  71 | Loss: -0.29 | C-Index: 0.6899 | Brier Score: 0.1478
# Epoch:  72 | Loss: -0.30 | C-Index: 0.6907 | Brier Score: 0.1477
# Epoch:  73 | Loss: -0.30 | C-Index: 0.6912 | Brier Score: 0.1476
# Epoch:  74 | Loss: -0.30 | C-Index: 0.6922 | Brier Score: 0.1474
# Epoch:  75 | Loss: -0.30 | C-Index: 0.6927 | Brier Score: 0.1473
# Epoch:  76 | Loss: -0.31 | C-Index: 0.6927 | Brier Score: 0.1472
# Epoch:  77 | Loss: -0.31 | C-Index: 0.6941 | Brier Score: 0.1471
# Epoch:  78 | Loss: -0.31 | C-Index: 0.6943 | Brier Score: 0.1470
# Epoch:  79 | Loss: -0.31 | C-Index: 0.6949 | Brier Score: 0.1469
# Epoch:  80 | Loss: -0.31 | C-Index: 0.6958 | Brier Score: 0.1468
# Epoch:  81 | Loss: -0.32 | C-Index: 0.6962 | Brier Score: 0.1467
# Epoch:  82 | Loss: -0.32 | C-Index: 0.6976 | Brier Score: 0.1466
# Epoch:  83 | Loss: -0.32 | C-Index: 0.6985 | Brier Score: 0.1465
# Epoch:  84 | Loss: -0.32 | C-Index: 0.6987 | Brier Score: 0.1464
# Epoch:  85 | Loss: -0.32 | C-Index: 0.6999 | Brier Score: 0.1464
# Epoch:  86 | Loss: -0.33 | C-Index: 0.7005 | Brier Score: 0.1463
# Epoch:  87 | Loss: -0.33 | C-Index: 0.7012 | Brier Score: 0.1462
# Epoch:  88 | Loss: -0.33 | C-Index: 0.7012 | Brier Score: 0.1462
# Epoch:  89 | Loss: -0.33 | C-Index: 0.7016 | Brier Score: 0.1461
# Epoch:  90 | Loss: -0.33 | C-Index: 0.7031 | Brier Score: 0.1461
# Epoch:  91 | Loss: -0.34 | C-Index: 0.7034 | Brier Score: 0.1460
# Epoch:  92 | Loss: -0.34 | C-Index: 0.7034 | Brier Score: 0.1459
# Epoch:  93 | Loss: -0.34 | C-Index: 0.7046 | Brier Score: 0.1459
# Epoch:  94 | Loss: -0.34 | C-Index: 0.7049 | Brier Score: 0.1459
# Epoch:  95 | Loss: -0.34 | C-Index: 0.7049 | Brier Score: 0.1458
# Epoch:  96 | Loss: -0.35 | C-Index: 0.7054 | Brier Score: 0.1458
# Epoch:  97 | Loss: -0.35 | C-Index: 0.7057 | Brier Score: 0.1457
# Epoch:  98 | Loss: -0.35 | C-Index: 0.7057 | Brier Score: 0.1457
# Epoch:  99 | Loss: -0.35 | C-Index: 0.7059 | Brier Score: 0.1457
# Epoch: 100 | Loss: -0.35 | C-Index: 0.7063 | Brier Score: 0.1456
# Epoch: 101 | Loss: -0.36 | C-Index: 0.7065 | Brier Score: 0.1456
# Epoch: 102 | Loss: -0.36 | C-Index: 0.7069 | Brier Score: 0.1456
# Epoch: 103 | Loss: -0.36 | C-Index: 0.7067 | Brier Score: 0.1456
# Epoch: 104 | Loss: -0.36 | C-Index: 0.7073 | Brier Score: 0.1456
# Epoch: 105 | Loss: -0.36 | C-Index: 0.7076 | Brier Score: 0.1456
# Epoch: 106 | Loss: -0.36 | C-Index: 0.7076 | Brier Score: 0.1455
# Epoch: 107 | Loss: -0.37 | C-Index: 0.7076 | Brier Score: 0.1455
# Epoch: 108 | Loss: -0.37 | C-Index: 0.7083 | Brier Score: 0.1455
# Epoch: 109 | Loss: -0.37 | C-Index: 0.7087 | Brier Score: 0.1456

# %%
# Integrated mean Prediction Error Curves"
print("\n\nMean integrated prediction error curves:\n")

print("Partial Likelihood           : {}".format(
    np.trapz(y=prediction_error_curves_PartialLikelihood.mean(), x=EVALUATION_TIMES_PEC)))
print("Stratified Partial Likelihood: {}".format(
    np.trapz(y=prediction_error_curves_StratifiedPartialLikelihood.mean(), x=EVALUATION_TIMES_PEC)))
print("Ranking Loss                 : {}".format(
    np.trapz(y=prediction_error_curves_RankingLoss.mean(), x=EVALUATION_TIMES_PEC)))
print("Stratified Ranking Loss      : {}".format(
    np.trapz(y=prediction_error_curves_StratifiedRankingLoss.mean(), x=EVALUATION_TIMES_PEC)))
# Out:
# Mean integrated prediction error curves:
#
# Partial Likelihood           : 137.25527259723458
# Stratified Partial Likelihood: 134.74925689800295
# Ranking Loss                 : 137.26841330375802
# Stratified Ranking Loss      : 134.85102587961828

# %%
# Concordance Index
print("\n\nMean C-Index:\n")
print(concordance_index_summary_df.mean())
# Out:
# Mean C-Index:
#
# Partial Likelihood               0.702982
# Stratified Partial Likelihood    0.701546
# Ranking Loss                     0.699223
# Stratified Ranking Loss          0.695410
# dtype: float64

# %%
# SHAP evaluation for GLIOMA patients.

glioma_patients = data.loc[data.tumor_type == "GLIOMA"].index

gene_counts_glioma = gene_counts.loc[glioma_patients].to_numpy()

shap_values_glioma_pl = shap_values_PartialLikelihood.astype('float64').loc[glioma_patients].to_numpy()
shap_values_glioma_spl = shap_values_StratifiedPartialLikelihood.astype('float64').loc[glioma_patients].to_numpy()
shap_values_glioma_rl = shap_values_RankingLoss.astype('float64').loc[glioma_patients].to_numpy()
shap_values_glioma_srl = shap_values_StratifiedRankingLoss.astype('float64').loc[glioma_patients].to_numpy()

print("\nSHAP summary plot Partial Likelihood")
shap.summary_plot(shap_values_glioma_pl, gene_counts_glioma, feature_names=gene_names, show=True)
plt.clf()

print("\nSHAP summary plot Stratified Partial Likelihood")
shap.summary_plot(shap_values_glioma_spl, gene_counts_glioma, feature_names=gene_names, show=True)
plt.clf()

print("\nSHAP summary plot Ranking Loss")
shap.summary_plot(shap_values_glioma_rl, gene_counts_glioma, feature_names=gene_names, show=True)
plt.clf()

print("\nSHAP summary plot Stratified Ranking Loss")
shap.summary_plot(shap_values_glioma_srl, gene_counts_glioma, feature_names=gene_names, show=True)
plt.clf()
# Out:
# SHAP summary plot Partial Likelihood
# SHAP summary plot Stratified Partial Likelihood
# SHAP summary plot Ranking Loss
# SHAP summary plot Stratified Ranking Loss
